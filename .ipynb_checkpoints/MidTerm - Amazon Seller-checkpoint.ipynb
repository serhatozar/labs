# %%
import pandas as pd

# %%
df = pd.read_excel('Amazon_Seller_Data_20_21.xlsx')
df
# Out:
#       UNIQUE_ACCOUNT_IDENTIFIER ACTIVITY_PERIOD SALES_CHANNEL MARKETPLACE  \
# 0                           NaN      2020-03-01           AFN   amazon.de
# 1                           NaN      2020-03-01           AFN   amazon.de
# 2                           NaN      2020-03-01           AFN   amazon.de
# 3                           NaN      2020-03-01           AFN   amazon.de
# 4                           NaN      2020-03-01           AFN   amazon.de
# ...                         ...             ...           ...         ...
# 7618                        NaN      2021-12-01           AFN   amazon.it
# 7619                        NaN      2021-12-01           AFN         NaN
# 7620                        NaN      2021-12-01           AFN         NaN
# 7621                        NaN      2021-12-01           AFN         NaN
# 7622                        NaN      2021-12-01           AFN         NaN
#
#      PROGRAM_TYPE TRANSACTION_TYPE TRANSACTION_EVENT_ID  \
# 0             NaN             SALE  305-4342416-8301160
# 1             NaN             SALE  305-4091689-0457120
# 2             NaN             SALE  305-1098454-9020302
# 3             NaN             SALE  304-9838863-2900348
# 4             NaN             SALE  304-3652837-5602768
# ...           ...              ...                  ...
# 7618      REGULAR           REFUND  406-9354703-8706767
# 7619      REGULAR      FC_TRANSFER          56411009993
# 7620      REGULAR      FC_TRANSFER          56324009993
# 7621      REGULAR      FC_TRANSFER           4894921609
# 7622      REGULAR      FC_TRANSFER           4894712609
#
#                 ACTIVITY_TRANSACTION_ID TAX_CALCULATION_DATE  \
# 0                             DGmBCcyns           29-03-2020
# 1                             D3kBYlFQL           30-03-2020
# 2                             D6jkGQWRF           30-03-2020
# 3                             DV6ZSvW6F           31-03-2020
# 4                             DVH3s64lc           29-03-2020
# ...                                 ...                  ...
# 7618  amzn1:crow:0kyx8yB9TvGAxwAiIcoBTQ           24-11-2021
# 7619                        56411009993                  NaN
# 7620                        56324009993                  NaN
# 7621                         4894921609                  NaN
# 7622                         4894712609                  NaN
#
#      TRANSACTION_DEPART_DATE  ... VAT_INV_EXCHANGE_RATE  \
# 0                 31-03-2020  ...                   NaN
# 1                 31-03-2020  ...                   NaN
# 2                 31-03-2020  ...                   NaN
# 3                 31-03-2020  ...                   NaN
# 4                 31-03-2020  ...                   NaN
# ...                      ...  ...                   ...
# 7618                     NaN  ...                   NaN
# 7619              01-12-2021  ...                   NaN
# 7620              01-12-2021  ...                   NaN
# 7621              01-12-2021  ...                   NaN
# 7622              01-12-2021  ...                   NaN
#
#      VAT_INV_EXCHANGE_RATE_DATE EXPORT_OUTSIDE_EU  \
# 0                           NaN                NO
# 1                           NaN                NO
# 2                           NaN                NO
# 3                           NaN                NO
# 4                           NaN                NO
# ...                         ...               ...
# 7618                        NaN                NO
# 7619                        NaN               NaN
# 7620                        NaN               NaN
# 7621                        NaN               NaN
# 7622                        NaN               NaN
#
#                                             INVOICE_URL BUYER_NAME  \
# 0     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 1     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 2     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 3     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 4     https://www.Amazon.de/gp/invoice/download.html...        NaN
# ...                                                 ...        ...
# 7618  https://www.Amazon.it/gp/invoice/download.html...        NaN
# 7619                                                NaN        NaN
# 7620                                                NaN        NaN
# 7621                                                NaN        NaN
# 7622                                                NaN        NaN
#
#      ARRIVAL_ADDRESS SUPPLIER_NAME  SUPPLIER_VAT_NUMBER  TAX_REPORTING_SCHEME  \
# 0                NaN           NaN                  NaN                   NaN
# 1                NaN           NaN                  NaN                   NaN
# 2                NaN           NaN                  NaN                   NaN
# 3                NaN           NaN                  NaN                   NaN
# 4                NaN           NaN                  NaN                   NaN
# ...              ...           ...                  ...                   ...
# 7618             NaN           NaN                  NaN               REGULAR
# 7619             NaN           NaN                  NaN                   NaN
# 7620             NaN           NaN                  NaN                   NaN
# 7621             NaN           NaN                  NaN                   NaN
# 7622             NaN           NaN                  NaN                   NaN
#
#       TAX_COLLECTION_RESPONSIBILITY
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 7618                         SELLER
# 7619                            NaN
# 7620                            NaN
# 7621                            NaN
# 7622                            NaN
#
# [7623 rows x 97 columns]

# %%
df.head()
# Out:
#    UNIQUE_ACCOUNT_IDENTIFIER ACTIVITY_PERIOD SALES_CHANNEL MARKETPLACE  \
# 0                        NaN      2020-03-01           AFN   amazon.de
# 1                        NaN      2020-03-01           AFN   amazon.de
# 2                        NaN      2020-03-01           AFN   amazon.de
# 3                        NaN      2020-03-01           AFN   amazon.de
# 4                        NaN      2020-03-01           AFN   amazon.de
#
#   PROGRAM_TYPE TRANSACTION_TYPE TRANSACTION_EVENT_ID ACTIVITY_TRANSACTION_ID  \
# 0          NaN             SALE  305-4342416-8301160               DGmBCcyns
# 1          NaN             SALE  305-4091689-0457120               D3kBYlFQL
# 2          NaN             SALE  305-1098454-9020302               D6jkGQWRF
# 3          NaN             SALE  304-9838863-2900348               DV6ZSvW6F
# 4          NaN             SALE  304-3652837-5602768               DVH3s64lc
#
#   TAX_CALCULATION_DATE TRANSACTION_DEPART_DATE  ... VAT_INV_EXCHANGE_RATE  \
# 0           29-03-2020              31-03-2020  ...                   NaN
# 1           30-03-2020              31-03-2020  ...                   NaN
# 2           30-03-2020              31-03-2020  ...                   NaN
# 3           31-03-2020              31-03-2020  ...                   NaN
# 4           29-03-2020              31-03-2020  ...                   NaN
#
#   VAT_INV_EXCHANGE_RATE_DATE EXPORT_OUTSIDE_EU  \
# 0                        NaN                NO
# 1                        NaN                NO
# 2                        NaN                NO
# 3                        NaN                NO
# 4                        NaN                NO
#
#                                          INVOICE_URL BUYER_NAME  \
# 0  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 1  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 2  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 3  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 4  https://www.Amazon.de/gp/invoice/download.html...        NaN
#
#   ARRIVAL_ADDRESS SUPPLIER_NAME  SUPPLIER_VAT_NUMBER  TAX_REPORTING_SCHEME  \
# 0             NaN           NaN                  NaN                   NaN
# 1             NaN           NaN                  NaN                   NaN
# 2             NaN           NaN                  NaN                   NaN
# 3             NaN           NaN                  NaN                   NaN
# 4             NaN           NaN                  NaN                   NaN
#
#    TAX_COLLECTION_RESPONSIBILITY
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 97 columns]

# %%
df.columns.unique()
# Out:
# Index(['UNIQUE_ACCOUNT_IDENTIFIER', 'ACTIVITY_PERIOD', 'SALES_CHANNEL',
#        'MARKETPLACE', 'PROGRAM_TYPE', 'TRANSACTION_TYPE',
#        'TRANSACTION_EVENT_ID', 'ACTIVITY_TRANSACTION_ID',
#        'TAX_CALCULATION_DATE', 'TRANSACTION_DEPART_DATE',
#        'TRANSACTION_ARRIVAL_DATE', 'TRANSACTION_COMPLETE_DATE', 'SELLER_SKU',
#        'ASIN', 'Product_Name', 'Product_Type', 'ITEM_DESCRIPTION',
#        'ITEM_MANUFACTURE_COUNTRY', 'QTY', 'ITEM_WEIGHT',
#        'TOTAL_ACTIVITY_WEIGHT', 'COST_PRICE_OF_ITEMS',
#        'PRICE_OF_ITEMS_AMT_VAT_EXCL', 'PROMO_PRICE_OF_ITEMS_AMT_VAT_EXCL',
#        'TOTAL_PRICE_OF_ITEMS_AMT_VAT_EXCL', 'SHIP_CHARGE_AMT_VAT_EXCL',
#        'PROMO_SHIP_CHARGE_AMT_VAT_EXCL', 'TOTAL_SHIP_CHARGE_AMT_VAT_EXCL',
#        'GIFT_WRAP_AMT_VAT_EXCL', 'PROMO_GIFT_WRAP_AMT_VAT_EXCL',
#        'TOTAL_GIFT_WRAP_AMT_VAT_EXCL', 'TOTAL_ACTIVITY_VALUE_AMT_VAT_EXCL',
#        'PRICE_OF_ITEMS_VAT_RATE_PERCENT', 'PRICE_OF_ITEMS_VAT_AMT',
#        'PROMO_PRICE_OF_ITEMS_VAT_AMT', 'TOTAL_PRICE_OF_ITEMS_VAT_AMT',
#        'SHIP_CHARGE_VAT_RATE_PERCENT', 'SHIP_CHARGE_VAT_AMT',
#        'PROMO_SHIP_CHARGE_VAT_AMT', 'TOTAL_SHIP_CHARGE_VAT_AMT',
#        'GIFT_WRAP_VAT_RATE_PERCENT', 'GIFT_WRAP_VAT_AMT',
#        'PROMO_GIFT_WRAP_VAT_AMT', 'TOTAL_GIFT_WRAP_VAT_AMT',
#        'TOTAL_ACTIVITY_VALUE_VAT_AMT', 'PRICE_OF_ITEMS_AMT_VAT_INCL',
#        'PROMO_PRICE_OF_ITEMS_AMT_VAT_INCL',
#        'TOTAL_PRICE_OF_ITEMS_AMT_VAT_INCL', 'SHIP_CHARGE_AMT_VAT_INCL',
#        'PROMO_SHIP_CHARGE_AMT_VAT_INCL', 'TOTAL_SHIP_CHARGE_AMT_VAT_INCL',
#        'GIFT_WRAP_AMT_VAT_INCL', 'PROMO_GIFT_WRAP_AMT_VAT_INCL',
#        'TOTAL_GIFT_WRAP_AMT_VAT_INCL', 'TOTAL_ACTIVITY_VALUE_AMT_VAT_INCL',
#        'TRANSACTION_CURRENCY_CODE', 'COMMODITY_CODE',
#        'STATISTICAL_CODE_DEPART', 'STATISTICAL_CODE_ARRIVAL',
#        'COMMODITY_CODE_SUPPLEMENTARY_UNIT', 'ITEM_QTY_SUPPLEMENTARY_UNIT',
#        'TOTAL_ACTIVITY_SUPPLEMENTARY_UNIT', 'PRODUCT_TAX_CODE',
#        'DEPATURE_CITY', 'DEPARTURE_COUNTRY', 'DEPARTURE_POST_CODE',
#        'ARRIVAL_CITY', 'ARRIVAL_COUNTRY', 'ARRIVAL_POST_CODE',
#        'SALE_DEPART_COUNTRY', 'SALE_ARRIVAL_COUNTRY', 'TRANSPORTATION_MODE',
#        'DELIVERY_CONDITIONS', 'SELLER_DEPART_VAT_NUMBER_COUNTRY',
#        'SELLER_DEPART_COUNTRY_VAT_NUMBER', 'SELLER_ARRIVAL_VAT_NUMBER_COUNTRY',
#        'SELLER_ARRIVAL_COUNTRY_VAT_NUMBER',
#        'TRANSACTION_SELLER_VAT_NUMBER_COUNTRY',
#        'TRANSACTION_SELLER_VAT_NUMBER', 'BUYER_VAT_NUMBER_COUNTRY',
#        'BUYER_VAT_NUMBER', 'VAT_CALCULATION_IMPUTATION_COUNTRY',
#        'TAXABLE_JURISDICTION', 'TAXABLE_JURISDICTION_LEVEL', 'VAT_INV_NUMBER',
#        'VAT_INV_CONVERTED_AMT', 'VAT_INV_CURRENCY_CODE',
#        'VAT_INV_EXCHANGE_RATE', 'VAT_INV_EXCHANGE_RATE_DATE',
#        'EXPORT_OUTSIDE_EU', 'INVOICE_URL', 'BUYER_NAME', 'ARRIVAL_ADDRESS',
#        'SUPPLIER_NAME', 'SUPPLIER_VAT_NUMBER', 'TAX_REPORTING_SCHEME',
#        'TAX_COLLECTION_RESPONSIBILITY'],
#       dtype='object')

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       UNIQUE_ACCOUNT_IDENTIFIER ACTIVITY_PERIOD SALES_CHANNEL MARKETPLACE  \
# 0                           NaN      2020-03-01           AFN   amazon.de
# 1                           NaN      2020-03-01           AFN   amazon.de
# 2                           NaN      2020-03-01           AFN   amazon.de
# 3                           NaN      2020-03-01           AFN   amazon.de
# 4                           NaN      2020-03-01           AFN   amazon.de
# ...                         ...             ...           ...         ...
# 7618                        NaN      2021-12-01           AFN   amazon.it
# 7619                        NaN      2021-12-01           AFN         NaN
# 7620                        NaN      2021-12-01           AFN         NaN
# 7621                        NaN      2021-12-01           AFN         NaN
# 7622                        NaN      2021-12-01           AFN         NaN
#
#      PROGRAM_TYPE TRANSACTION_TYPE TRANSACTION_EVENT_ID  \
# 0             NaN             SALE  305-4342416-8301160
# 1             NaN             SALE  305-4091689-0457120
# 2             NaN             SALE  305-1098454-9020302
# 3             NaN             SALE  304-9838863-2900348
# 4             NaN             SALE  304-3652837-5602768
# ...           ...              ...                  ...
# 7618      REGULAR           REFUND  406-9354703-8706767
# 7619      REGULAR      FC_TRANSFER          56411009993
# 7620      REGULAR      FC_TRANSFER          56324009993
# 7621      REGULAR      FC_TRANSFER           4894921609
# 7622      REGULAR      FC_TRANSFER           4894712609
#
#                 ACTIVITY_TRANSACTION_ID TAX_CALCULATION_DATE  \
# 0                             DGmBCcyns           29-03-2020
# 1                             D3kBYlFQL           30-03-2020
# 2                             D6jkGQWRF           30-03-2020
# 3                             DV6ZSvW6F           31-03-2020
# 4                             DVH3s64lc           29-03-2020
# ...                                 ...                  ...
# 7618  amzn1:crow:0kyx8yB9TvGAxwAiIcoBTQ           24-11-2021
# 7619                        56411009993                  NaN
# 7620                        56324009993                  NaN
# 7621                         4894921609                  NaN
# 7622                         4894712609                  NaN
#
#      TRANSACTION_DEPART_DATE  ... VAT_INV_EXCHANGE_RATE  \
# 0                 31-03-2020  ...                   NaN
# 1                 31-03-2020  ...                   NaN
# 2                 31-03-2020  ...                   NaN
# 3                 31-03-2020  ...                   NaN
# 4                 31-03-2020  ...                   NaN
# ...                      ...  ...                   ...
# 7618                     NaN  ...                   NaN
# 7619              01-12-2021  ...                   NaN
# 7620              01-12-2021  ...                   NaN
# 7621              01-12-2021  ...                   NaN
# 7622              01-12-2021  ...                   NaN
#
#      VAT_INV_EXCHANGE_RATE_DATE EXPORT_OUTSIDE_EU  \
# 0                           NaN                NO
# 1                           NaN                NO
# 2                           NaN                NO
# 3                           NaN                NO
# 4                           NaN                NO
# ...                         ...               ...
# 7618                        NaN                NO
# 7619                        NaN               NaN
# 7620                        NaN               NaN
# 7621                        NaN               NaN
# 7622                        NaN               NaN
#
#                                             INVOICE_URL BUYER_NAME  \
# 0     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 1     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 2     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 3     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 4     https://www.Amazon.de/gp/invoice/download.html...        NaN
# ...                                                 ...        ...
# 7618  https://www.Amazon.it/gp/invoice/download.html...        NaN
# 7619                                                NaN        NaN
# 7620                                                NaN        NaN
# 7621                                                NaN        NaN
# 7622                                                NaN        NaN
#
#      ARRIVAL_ADDRESS SUPPLIER_NAME  SUPPLIER_VAT_NUMBER  TAX_REPORTING_SCHEME  \
# 0                NaN           NaN                  NaN                   NaN
# 1                NaN           NaN                  NaN                   NaN
# 2                NaN           NaN                  NaN                   NaN
# 3                NaN           NaN                  NaN                   NaN
# 4                NaN           NaN                  NaN                   NaN
# ...              ...           ...                  ...                   ...
# 7618             NaN           NaN                  NaN               REGULAR
# 7619             NaN           NaN                  NaN                   NaN
# 7620             NaN           NaN                  NaN                   NaN
# 7621             NaN           NaN                  NaN                   NaN
# 7622             NaN           NaN                  NaN                   NaN
#
#       TAX_COLLECTION_RESPONSIBILITY
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 7618                         SELLER
# 7619                            NaN
# 7620                            NaN
# 7621                            NaN
# 7622                            NaN
#
# [7623 rows x 97 columns]>

# %%
df = df.drop(columns=['UNIQUE_ACCOUNT_IDENTIFIER', 'SALES_CHANNEL', 'PROGRAM_TYPE', 'TRANSACTION_EVENT_ID', 'ACTIVITY_TRANSACTION_ID', 'SELLER_SKU', 'ITEM_MANUFACTURE_COUNTRY','COMMODITY_CODE',
       'STATISTICAL_CODE_DEPART', 'STATISTICAL_CODE_ARRIVAL', 'COST_PRICE_OF_ITEMS', 'PROMO_GIFT_WRAP_AMT_VAT_EXCL', ''
       'COMMODITY_CODE_SUPPLEMENTARY_UNIT', 'ITEM_QTY_SUPPLEMENTARY_UNIT',
       'TOTAL_ACTIVITY_SUPPLEMENTARY_UNIT', 'PRODUCT_TAX_CODE',
       'BUYER_VAT_NUMBER', 'VAT_INV_NUMBER', 'TAXABLE_JURISDICTION_LEVEL', 'INVOICE_URL', 'BUYER_NAME', 'ARRIVAL_ADDRESS', 'SUPPLIER_NAME', 'SUPPLIER_VAT_NUMBER',
       'VAT_INV_CONVERTED_AMT', 'VAT_INV_CURRENCY_CODE',
       'VAT_INV_EXCHANGE_RATE', 'VAT_INV_EXCHANGE_RATE_DATE', 'ITEM_DESCRIPTION', 'TAX_CALCULATION_DATE', 'TRANSACTION_DEPART_DATE',
       'TRANSACTION_ARRIVAL_DATE', 'TRANSACTION_COMPLETE_DATE', 'PROMO_SHIP_CHARGE_AMT_VAT_EXCL', 'PROMO_PRICE_OF_ITEMS_AMT_VAT_EXCL', 'PROMO_PRICE_OF_ITEMS_VAT_AMT', 'PROMO_SHIP_CHARGE_VAT_AMT', 'PROMO_GIFT_WRAP_VAT_AMT', 'PROMO_PRICE_OF_ITEMS_AMT_VAT_INCL', 'PROMO_SHIP_CHARGE_AMT_VAT_INCL', 'PROMO_GIFT_WRAP_AMT_VAT_INCL',
    'GIFT_WRAP_AMT_VAT_EXCL', 'TOTAL_GIFT_WRAP_AMT_VAT_EXCL', 'GIFT_WRAP_VAT_RATE_PERCENT', 'GIFT_WRAP_VAT_AMT', 'TOTAL_GIFT_WRAP_VAT_AMT', 'GIFT_WRAP_AMT_VAT_INCL', 'TOTAL_GIFT_WRAP_AMT_VAT_INCL', 'SELLER_DEPART_VAT_NUMBER_COUNTRY',
       'SELLER_DEPART_COUNTRY_VAT_NUMBER', 'SELLER_ARRIVAL_VAT_NUMBER_COUNTRY',
       'SELLER_ARRIVAL_COUNTRY_VAT_NUMBER',
       'TRANSACTION_SELLER_VAT_NUMBER_COUNTRY',
       'TRANSACTION_SELLER_VAT_NUMBER', 'BUYER_VAT_NUMBER_COUNTRY', 'VAT_CALCULATION_IMPUTATION_COUNTRY'])
df
# Out:
#      ACTIVITY_PERIOD MARKETPLACE TRANSACTION_TYPE        ASIN  \
# 0         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 1         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 2         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 3         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 4         2020-03-01   amazon.de             SALE  B083LZ1GJD
# ...              ...         ...              ...         ...
# 7618      2021-12-01   amazon.it           REFUND  B082J64726
# 7619      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7620      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7621      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7622      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
#
#                                 Product_Name Product_Type  QTY  ITEM_WEIGHT  \
# 0     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 1     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 2     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 3     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 4     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    2         0.55
# ...                                      ...          ...  ...          ...
# 7618                Immersion Heater 3.000 W           3K    1          NaN
# 7619               Baby Carrier (Lilac Grey)   Lilac Grey   14         0.87
# 7620               Baby Carrier (Lilac Grey)   Lilac Grey    2         0.87
# 7621               Baby Carrier (Lilac Grey)   Lilac Grey    9         0.87
# 7622               Baby Carrier (Lilac Grey)   Lilac Grey    3         0.87
#
#       TOTAL_ACTIVITY_WEIGHT  PRICE_OF_ITEMS_AMT_VAT_EXCL  ...  \
# 0                      0.55                        12.60  ...
# 1                      0.55                        12.60  ...
# 2                      0.55                        12.60  ...
# 3                      0.55                        16.80  ...
# 4                      1.10                        25.20  ...
# ...                     ...                          ...  ...
# 7618                    NaN                       -84.03  ...
# 7619                  12.18                          NaN  ...
# 7620                   1.74                          NaN  ...
# 7621                   7.83                          NaN  ...
# 7622                   2.61                          NaN  ...
#
#       ARRIVAL_COUNTRY  ARRIVAL_POST_CODE  SALE_DEPART_COUNTRY  \
# 0                  DE              30900                   DE
# 1                  DE              79761                   DE
# 2                  DE              14469                   DE
# 3                  DE              02794                   DE
# 4                  DE              89312                   DE
# ...               ...                ...                  ...
# 7618              NaN              76125                   DE
# 7619               FR              57685                  NaN
# 7620               FR              57685                  NaN
# 7621               FR              59553                  NaN
# 7622               FR              59553                  NaN
#
#       SALE_ARRIVAL_COUNTRY  TRANSPORTATION_MODE  DELIVERY_CONDITIONS  \
# 0                       DE  CONSIGNMENT_BY_POST                  DAP
# 1                       DE  CONSIGNMENT_BY_POST                  DAP
# 2                       DE  CONSIGNMENT_BY_POST                  DAP
# 3                       DE  CONSIGNMENT_BY_POST                  DAP
# 4                       DE  CONSIGNMENT_BY_POST                  DAP
# ...                    ...                  ...                  ...
# 7618                    IT  CONSIGNMENT_BY_POST                  DAP
# 7619                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7620                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7621                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7622                   NaN    TRANSPORT_BY_ROAD                  XXX
#
#       TAXABLE_JURISDICTION  EXPORT_OUTSIDE_EU  TAX_REPORTING_SCHEME  \
# 0                  GERMANY                 NO                   NaN
# 1                  GERMANY                 NO                   NaN
# 2                  GERMANY                 NO                   NaN
# 3                  GERMANY                 NO                   NaN
# 4                  GERMANY                 NO                   NaN
# ...                    ...                ...                   ...
# 7618               GERMANY                 NO               REGULAR
# 7619                   NaN                NaN                   NaN
# 7620                   NaN                NaN                   NaN
# 7621                   NaN                NaN                   NaN
# 7622                   NaN                NaN                   NaN
#
#       TAX_COLLECTION_RESPONSIBILITY
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 7618                         SELLER
# 7619                            NaN
# 7620                            NaN
# 7621                            NaN
# 7622                            NaN
#
# [7623 rows x 41 columns]

# %%
df.fillna('NaN')
# Out:
#      ACTIVITY_PERIOD MARKETPLACE TRANSACTION_TYPE        ASIN  \
# 0         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 1         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 2         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 3         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 4         2020-03-01   amazon.de             SALE  B083LZ1GJD
# ...              ...         ...              ...         ...
# 7618      2021-12-01   amazon.it           REFUND  B082J64726
# 7619      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7620      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7621      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7622      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
#
#                                 Product_Name Product_Type  QTY ITEM_WEIGHT  \
# 0     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1        0.55
# 1     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1        0.55
# 2     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1        0.55
# 3     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1        0.55
# 4     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    2        0.55
# ...                                      ...          ...  ...         ...
# 7618                Immersion Heater 3.000 W           3K    1         NaN
# 7619               Baby Carrier (Lilac Grey)   Lilac Grey   14        0.87
# 7620               Baby Carrier (Lilac Grey)   Lilac Grey    2        0.87
# 7621               Baby Carrier (Lilac Grey)   Lilac Grey    9        0.87
# 7622               Baby Carrier (Lilac Grey)   Lilac Grey    3        0.87
#
#      TOTAL_ACTIVITY_WEIGHT PRICE_OF_ITEMS_AMT_VAT_EXCL  ... ARRIVAL_COUNTRY  \
# 0                     0.55                        12.6  ...              DE
# 1                     0.55                        12.6  ...              DE
# 2                     0.55                        12.6  ...              DE
# 3                     0.55                        16.8  ...              DE
# 4                      1.1                        25.2  ...              DE
# ...                    ...                         ...  ...             ...
# 7618                   NaN                      -84.03  ...             NaN
# 7619                 12.18                         NaN  ...              FR
# 7620                  1.74                         NaN  ...              FR
# 7621                  7.83                         NaN  ...              FR
# 7622                  2.61                         NaN  ...              FR
#
#      ARRIVAL_POST_CODE SALE_DEPART_COUNTRY SALE_ARRIVAL_COUNTRY  \
# 0                30900                  DE                   DE
# 1                79761                  DE                   DE
# 2                14469                  DE                   DE
# 3                02794                  DE                   DE
# 4                89312                  DE                   DE
# ...                ...                 ...                  ...
# 7618             76125                  DE                   IT
# 7619             57685                 NaN                  NaN
# 7620             57685                 NaN                  NaN
# 7621             59553                 NaN                  NaN
# 7622             59553                 NaN                  NaN
#
#       TRANSPORTATION_MODE DELIVERY_CONDITIONS TAXABLE_JURISDICTION  \
# 0     CONSIGNMENT_BY_POST                 DAP              GERMANY
# 1     CONSIGNMENT_BY_POST                 DAP              GERMANY
# 2     CONSIGNMENT_BY_POST                 DAP              GERMANY
# 3     CONSIGNMENT_BY_POST                 DAP              GERMANY
# 4     CONSIGNMENT_BY_POST                 DAP              GERMANY
# ...                   ...                 ...                  ...
# 7618  CONSIGNMENT_BY_POST                 DAP              GERMANY
# 7619    TRANSPORT_BY_ROAD                 XXX                  NaN
# 7620    TRANSPORT_BY_ROAD                 XXX                  NaN
# 7621    TRANSPORT_BY_ROAD                 XXX                  NaN
# 7622    TRANSPORT_BY_ROAD                 XXX                  NaN
#
#      EXPORT_OUTSIDE_EU TAX_REPORTING_SCHEME TAX_COLLECTION_RESPONSIBILITY
# 0                   NO                  NaN                           NaN
# 1                   NO                  NaN                           NaN
# 2                   NO                  NaN                           NaN
# 3                   NO                  NaN                           NaN
# 4                   NO                  NaN                           NaN
# ...                ...                  ...                           ...
# 7618                NO              REGULAR                        SELLER
# 7619               NaN                  NaN                           NaN
# 7620               NaN                  NaN                           NaN
# 7621               NaN                  NaN                           NaN
# 7622               NaN                  NaN                           NaN
#
# [7623 rows x 41 columns]

# %%
df.reset_index(drop=True)
# Out:
#      ACTIVITY_PERIOD MARKETPLACE TRANSACTION_TYPE        ASIN  \
# 0         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 1         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 2         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 3         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 4         2020-03-01   amazon.de             SALE  B083LZ1GJD
# ...              ...         ...              ...         ...
# 7618      2021-12-01   amazon.it           REFUND  B082J64726
# 7619      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7620      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7621      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7622      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
#
#                                 Product_Name Product_Type  QTY  ITEM_WEIGHT  \
# 0     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 1     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 2     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 3     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 4     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    2         0.55
# ...                                      ...          ...  ...          ...
# 7618                Immersion Heater 3.000 W           3K    1          NaN
# 7619               Baby Carrier (Lilac Grey)   Lilac Grey   14         0.87
# 7620               Baby Carrier (Lilac Grey)   Lilac Grey    2         0.87
# 7621               Baby Carrier (Lilac Grey)   Lilac Grey    9         0.87
# 7622               Baby Carrier (Lilac Grey)   Lilac Grey    3         0.87
#
#       TOTAL_ACTIVITY_WEIGHT  PRICE_OF_ITEMS_AMT_VAT_EXCL  ...  \
# 0                      0.55                        12.60  ...
# 1                      0.55                        12.60  ...
# 2                      0.55                        12.60  ...
# 3                      0.55                        16.80  ...
# 4                      1.10                        25.20  ...
# ...                     ...                          ...  ...
# 7618                    NaN                       -84.03  ...
# 7619                  12.18                          NaN  ...
# 7620                   1.74                          NaN  ...
# 7621                   7.83                          NaN  ...
# 7622                   2.61                          NaN  ...
#
#       ARRIVAL_COUNTRY  ARRIVAL_POST_CODE  SALE_DEPART_COUNTRY  \
# 0                  DE              30900                   DE
# 1                  DE              79761                   DE
# 2                  DE              14469                   DE
# 3                  DE              02794                   DE
# 4                  DE              89312                   DE
# ...               ...                ...                  ...
# 7618              NaN              76125                   DE
# 7619               FR              57685                  NaN
# 7620               FR              57685                  NaN
# 7621               FR              59553                  NaN
# 7622               FR              59553                  NaN
#
#       SALE_ARRIVAL_COUNTRY  TRANSPORTATION_MODE  DELIVERY_CONDITIONS  \
# 0                       DE  CONSIGNMENT_BY_POST                  DAP
# 1                       DE  CONSIGNMENT_BY_POST                  DAP
# 2                       DE  CONSIGNMENT_BY_POST                  DAP
# 3                       DE  CONSIGNMENT_BY_POST                  DAP
# 4                       DE  CONSIGNMENT_BY_POST                  DAP
# ...                    ...                  ...                  ...
# 7618                    IT  CONSIGNMENT_BY_POST                  DAP
# 7619                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7620                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7621                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7622                   NaN    TRANSPORT_BY_ROAD                  XXX
#
#       TAXABLE_JURISDICTION  EXPORT_OUTSIDE_EU  TAX_REPORTING_SCHEME  \
# 0                  GERMANY                 NO                   NaN
# 1                  GERMANY                 NO                   NaN
# 2                  GERMANY                 NO                   NaN
# 3                  GERMANY                 NO                   NaN
# 4                  GERMANY                 NO                   NaN
# ...                    ...                ...                   ...
# 7618               GERMANY                 NO               REGULAR
# 7619                   NaN                NaN                   NaN
# 7620                   NaN                NaN                   NaN
# 7621                   NaN                NaN                   NaN
# 7622                   NaN                NaN                   NaN
#
#       TAX_COLLECTION_RESPONSIBILITY
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 7618                         SELLER
# 7619                            NaN
# 7620                            NaN
# 7621                            NaN
# 7622                            NaN
#
# [7623 rows x 41 columns]

# %%
def lower_case_column_names(columns):
    df.columns = [i.lower() for i in df.columns]
    return df

# %%
lower_case_column_names(df)
# Out:
#      activity_period marketplace transaction_type        asin  \
# 0         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 1         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 2         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 3         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 4         2020-03-01   amazon.de             SALE  B083LZ1GJD
# ...              ...         ...              ...         ...
# 7618      2021-12-01   amazon.it           REFUND  B082J64726
# 7619      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7620      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7621      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7622      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
#
#                                 product_name product_type  qty  item_weight  \
# 0     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 1     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 2     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 3     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 4     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    2         0.55
# ...                                      ...          ...  ...          ...
# 7618                Immersion Heater 3.000 W           3K    1          NaN
# 7619               Baby Carrier (Lilac Grey)   Lilac Grey   14         0.87
# 7620               Baby Carrier (Lilac Grey)   Lilac Grey    2         0.87
# 7621               Baby Carrier (Lilac Grey)   Lilac Grey    9         0.87
# 7622               Baby Carrier (Lilac Grey)   Lilac Grey    3         0.87
#
#       total_activity_weight  price_of_items_amt_vat_excl  ...  \
# 0                      0.55                        12.60  ...
# 1                      0.55                        12.60  ...
# 2                      0.55                        12.60  ...
# 3                      0.55                        16.80  ...
# 4                      1.10                        25.20  ...
# ...                     ...                          ...  ...
# 7618                    NaN                       -84.03  ...
# 7619                  12.18                          NaN  ...
# 7620                   1.74                          NaN  ...
# 7621                   7.83                          NaN  ...
# 7622                   2.61                          NaN  ...
#
#       arrival_country  arrival_post_code  sale_depart_country  \
# 0                  DE              30900                   DE
# 1                  DE              79761                   DE
# 2                  DE              14469                   DE
# 3                  DE              02794                   DE
# 4                  DE              89312                   DE
# ...               ...                ...                  ...
# 7618              NaN              76125                   DE
# 7619               FR              57685                  NaN
# 7620               FR              57685                  NaN
# 7621               FR              59553                  NaN
# 7622               FR              59553                  NaN
#
#       sale_arrival_country  transportation_mode  delivery_conditions  \
# 0                       DE  CONSIGNMENT_BY_POST                  DAP
# 1                       DE  CONSIGNMENT_BY_POST                  DAP
# 2                       DE  CONSIGNMENT_BY_POST                  DAP
# 3                       DE  CONSIGNMENT_BY_POST                  DAP
# 4                       DE  CONSIGNMENT_BY_POST                  DAP
# ...                    ...                  ...                  ...
# 7618                    IT  CONSIGNMENT_BY_POST                  DAP
# 7619                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7620                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7621                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7622                   NaN    TRANSPORT_BY_ROAD                  XXX
#
#       taxable_jurisdiction  export_outside_eu  tax_reporting_scheme  \
# 0                  GERMANY                 NO                   NaN
# 1                  GERMANY                 NO                   NaN
# 2                  GERMANY                 NO                   NaN
# 3                  GERMANY                 NO                   NaN
# 4                  GERMANY                 NO                   NaN
# ...                    ...                ...                   ...
# 7618               GERMANY                 NO               REGULAR
# 7619                   NaN                NaN                   NaN
# 7620                   NaN                NaN                   NaN
# 7621                   NaN                NaN                   NaN
# 7622                   NaN                NaN                   NaN
#
#       tax_collection_responsibility
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 7618                         SELLER
# 7619                            NaN
# 7620                            NaN
# 7621                            NaN
# 7622                            NaN
#
# [7623 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7623 entries, 0 to 7622
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   activity_period                    7623 non-null   datetime64[ns]
#  1   marketplace                        7153 non-null   object
#  2   transaction_type                   7623 non-null   object
#  3   asin                               7623 non-null   object
#  4   product_name                       7606 non-null   object
#  5   product_type                       7606 non-null   object
#  6   qty                                7623 non-null   int64
#  7   item_weight                        6889 non-null   float64
#  8   total_activity_weight              6889 non-null   float64
#  9   price_of_items_amt_vat_excl        6440 non-null   float64
#  10  total_price_of_items_amt_vat_excl  6440 non-null   float64
#  11  ship_charge_amt_vat_excl           3070 non-null   float64
#  12  total_ship_charge_amt_vat_excl     3070 non-null   float64
#  13  total_activity_value_amt_vat_excl  6446 non-null   float64
#  14  price_of_items_vat_rate_percent    6440 non-null   float64
#  15  price_of_items_vat_amt             6440 non-null   float64
#  16  total_price_of_items_vat_amt       6440 non-null   float64
#  17  ship_charge_vat_rate_percent       3070 non-null   float64
#  18  ship_charge_vat_amt                3070 non-null   float64
#  19  total_ship_charge_vat_amt          3070 non-null   float64
#  20  total_activity_value_vat_amt       6446 non-null   float64
#  21  price_of_items_amt_vat_incl        6455 non-null   float64
#  22  total_price_of_items_amt_vat_incl  6455 non-null   float64
#  23  ship_charge_amt_vat_incl           3085 non-null   float64
#  24  total_ship_charge_amt_vat_incl     3085 non-null   float64
#  25  total_activity_value_amt_vat_incl  6461 non-null   float64
#  26  transaction_currency_code          6461 non-null   object
#  27  depature_city                      7623 non-null   object
#  28  departure_country                  6889 non-null   object
#  29  departure_post_code                7613 non-null   object
#  30  arrival_city                       7623 non-null   object
#  31  arrival_country                    7046 non-null   object
#  32  arrival_post_code                  7620 non-null   object
#  33  sale_depart_country                7153 non-null   object
#  34  sale_arrival_country               7153 non-null   object
#  35  transportation_mode                7389 non-null   object
#  36  delivery_conditions                7400 non-null   object
#  37  taxable_jurisdiction               6446 non-null   object
#  38  export_outside_eu                  6446 non-null   object
#  39  tax_reporting_scheme               4704 non-null   object
#  40  tax_collection_responsibility      4704 non-null   object
# dtypes: datetime64[ns](1), float64(19), int64(1), object(20)
# memory usage: 2.4+ MB

# %%
df.to_csv('clean_amazon_sales.csv')

# %%
df.to_excel('clean_amazon_sales_20_21.xlsx')

# %%
df_corr = df.corr()
df_corr
# Out:
# C:\Users\Serhat\AppData\Local\Temp\ipykernel_18204\1378791828.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df.corr()
#                                         qty  item_weight  \
# qty                                1.000000    -0.001761
# item_weight                       -0.001761     1.000000
# total_activity_weight              0.234097     0.965140
# price_of_items_amt_vat_excl        0.167993    -0.045972
# total_price_of_items_amt_vat_excl  0.167989    -0.045726
# ship_charge_amt_vat_excl          -0.028177     0.163758
# total_ship_charge_amt_vat_excl    -0.010999     0.032374
# total_activity_value_amt_vat_excl  0.167905    -0.045883
# price_of_items_vat_rate_percent   -0.044950    -0.043794
# price_of_items_vat_amt             0.134875    -0.042738
# total_price_of_items_vat_amt       0.134825    -0.042526
# ship_charge_vat_rate_percent      -0.094448     0.012058
# ship_charge_vat_amt               -0.029545     0.168079
# total_ship_charge_vat_amt         -0.010877     0.018981
# total_activity_value_vat_amt       0.134713    -0.042622
# price_of_items_amt_vat_incl        0.165275    -0.047036
# total_price_of_items_amt_vat_incl  0.165262    -0.046779
# ship_charge_amt_vat_incl          -0.029115     0.170649
# total_ship_charge_amt_vat_incl    -0.011326     0.032307
# total_activity_value_amt_vat_incl  0.165210    -0.046961
#
#                                    total_activity_weight  \
# qty                                             0.234097
# item_weight                                     0.965140
# total_activity_weight                           1.000000
# price_of_items_amt_vat_excl                    -0.042974
# total_price_of_items_amt_vat_excl              -0.042736
# ship_charge_amt_vat_excl                       -0.017053
# total_ship_charge_amt_vat_excl                 -0.007455
# total_activity_value_amt_vat_excl              -0.042894
# price_of_items_vat_rate_percent                -0.043993
# price_of_items_vat_amt                         -0.040413
# total_price_of_items_vat_amt                   -0.040208
# ship_charge_vat_rate_percent                   -0.062470
# ship_charge_vat_amt                            -0.018335
# total_ship_charge_vat_amt                      -0.007762
# total_activity_value_vat_amt                   -0.040305
# price_of_items_amt_vat_incl                    -0.044038
# total_price_of_items_amt_vat_incl              -0.043790
# ship_charge_amt_vat_incl                       -0.017679
# total_ship_charge_amt_vat_incl                 -0.007708
# total_activity_value_amt_vat_incl              -0.043971
#
#                                    price_of_items_amt_vat_excl  \
# qty                                                   0.167993
# item_weight                                          -0.045972
# total_activity_weight                                -0.042974
# price_of_items_amt_vat_excl                           1.000000
# total_price_of_items_amt_vat_excl                     0.999621
# ship_charge_amt_vat_excl                              0.394770
# total_ship_charge_amt_vat_excl                        0.072272
# total_activity_value_amt_vat_excl                     0.999276
# price_of_items_vat_rate_percent                      -0.085486
# price_of_items_vat_amt                                0.882901
# total_price_of_items_vat_amt                          0.882526
# ship_charge_vat_rate_percent                         -0.099538
# ship_charge_vat_amt                                   0.343006
# total_ship_charge_vat_amt                             0.053600
# total_activity_value_vat_amt                          0.882262
# price_of_items_amt_vat_incl                           0.997417
# total_price_of_items_amt_vat_incl                     0.997027
# ship_charge_amt_vat_incl                              0.402137
# total_ship_charge_amt_vat_incl                        0.072924
# total_activity_value_amt_vat_incl                     0.996914
#
#                                    total_price_of_items_amt_vat_excl  \
# qty                                                         0.167989
# item_weight                                                -0.045726
# total_activity_weight                                      -0.042736
# price_of_items_amt_vat_excl                                 0.999621
# total_price_of_items_amt_vat_excl                           1.000000
# ship_charge_amt_vat_excl                                    0.393854
# total_ship_charge_amt_vat_excl                              0.072630
# total_activity_value_amt_vat_excl                           0.999665
# price_of_items_vat_rate_percent                            -0.085184
# price_of_items_vat_amt                                      0.882685
# total_price_of_items_vat_amt                                0.882942
# ship_charge_vat_rate_percent                               -0.099382
# ship_charge_vat_amt                                         0.341983
# total_ship_charge_vat_amt                                   0.053922
# total_activity_value_vat_amt                                0.882684
# price_of_items_amt_vat_incl                                 0.997057
# total_price_of_items_amt_vat_incl                           0.997417
# ship_charge_amt_vat_incl                                    0.401175
# total_ship_charge_amt_vat_incl                              0.073291
# total_activity_value_amt_vat_incl                           0.997314
#
#                                    ship_charge_amt_vat_excl  \
# qty                                               -0.028177
# item_weight                                        0.163758
# total_activity_weight                             -0.017053
# price_of_items_amt_vat_excl                        0.394770
# total_price_of_items_amt_vat_excl                  0.393854
# ship_charge_amt_vat_excl                           1.000000
# total_ship_charge_amt_vat_excl                     0.767635
# total_activity_value_amt_vat_excl                  0.429486
# price_of_items_vat_rate_percent                   -0.131646
# price_of_items_vat_amt                             0.223123
# total_price_of_items_vat_amt                       0.222416
# ship_charge_vat_rate_percent                       0.043021
# ship_charge_vat_amt                                0.702882
# total_ship_charge_vat_amt                          0.464205
# total_activity_value_vat_amt                       0.238198
# price_of_items_amt_vat_incl                        0.382130
# total_price_of_items_amt_vat_incl                  0.381205
# ship_charge_amt_vat_incl                           0.996020
# total_ship_charge_amt_vat_incl                     0.762715
# total_activity_value_amt_vat_incl                  0.415218
#
#                                    total_ship_charge_amt_vat_excl  \
# qty                                                     -0.010999
# item_weight                                              0.032374
# total_activity_weight                                   -0.007455
# price_of_items_amt_vat_excl                              0.072272
# total_price_of_items_amt_vat_excl                        0.072630
# ship_charge_amt_vat_excl                                 0.767635
# total_ship_charge_amt_vat_excl                           1.000000
# total_activity_value_amt_vat_excl                        0.121736
# price_of_items_vat_rate_percent                         -0.139062
# price_of_items_vat_amt                                  -0.020264
# total_price_of_items_vat_amt                            -0.019970
# ship_charge_vat_rate_percent                            -0.048328
# ship_charge_vat_amt                                      0.373418
# total_ship_charge_vat_amt                                0.631242
# total_activity_value_vat_amt                             0.002725
# price_of_items_amt_vat_incl                              0.060339
# total_price_of_items_amt_vat_incl                        0.060699
# ship_charge_amt_vat_incl                                 0.743762
# total_ship_charge_amt_vat_incl                           0.996464
# total_activity_value_amt_vat_incl                        0.107503
#
#                                    total_activity_value_amt_vat_excl  \
# qty                                                         0.167905
# item_weight                                                -0.045883
# total_activity_weight                                      -0.042894
# price_of_items_amt_vat_excl                                 0.999276
# total_price_of_items_amt_vat_excl                           0.999665
# ship_charge_amt_vat_excl                                    0.429486
# total_ship_charge_amt_vat_excl                              0.121736
# total_activity_value_amt_vat_excl                           1.000000
# price_of_items_vat_rate_percent                            -0.088550
# price_of_items_vat_amt                                      0.880970
# total_price_of_items_vat_amt                                0.881234
# ship_charge_vat_rate_percent                               -0.105959
# ship_charge_vat_amt                                         0.360223
# total_ship_charge_vat_amt                                   0.088236
# total_activity_value_vat_amt                                0.881346
# price_of_items_amt_vat_incl                                 0.996497
# total_price_of_items_amt_vat_incl                           0.996867
# ship_charge_amt_vat_incl                                    0.435738
# total_ship_charge_amt_vat_incl                              0.122567
# total_activity_value_amt_vat_incl                           0.997386
#
#                                    price_of_items_vat_rate_percent  \
# qty                                                      -0.044950
# item_weight                                              -0.043794
# total_activity_weight                                    -0.043993
# price_of_items_amt_vat_excl                              -0.085486
# total_price_of_items_amt_vat_excl                        -0.085184
# ship_charge_amt_vat_excl                                 -0.131646
# total_ship_charge_amt_vat_excl                           -0.139062
# total_activity_value_amt_vat_excl                        -0.088550
# price_of_items_vat_rate_percent                           1.000000
# price_of_items_vat_amt                                    0.253579
# total_price_of_items_vat_amt                              0.253462
# ship_charge_vat_rate_percent                              1.000000
# ship_charge_vat_amt                                       0.205012
# total_ship_charge_vat_amt                                 0.077649
# total_activity_value_vat_amt                              0.253825
# price_of_items_amt_vat_incl                              -0.034929
# total_price_of_items_amt_vat_incl                        -0.034680
# ship_charge_amt_vat_incl                                 -0.094135
# total_ship_charge_amt_vat_incl                           -0.120796
# total_activity_value_amt_vat_incl                        -0.037566
#
#                                    price_of_items_vat_amt  \
# qty                                              0.134875
# item_weight                                     -0.042738
# total_activity_weight                           -0.040413
# price_of_items_amt_vat_excl                      0.882901
# total_price_of_items_amt_vat_excl                0.882685
# ship_charge_amt_vat_excl                         0.223123
# total_ship_charge_amt_vat_excl                  -0.020264
# total_activity_value_amt_vat_excl                0.880970
# price_of_items_vat_rate_percent                  0.253579
# price_of_items_vat_amt                           1.000000
# total_price_of_items_vat_amt                     0.999699
# ship_charge_vat_rate_percent                     0.438218
# ship_charge_vat_amt                              0.464068
# total_ship_charge_vat_amt                        0.097304
# total_activity_value_vat_amt                     0.999550
# price_of_items_amt_vat_incl                      0.914348
# total_price_of_items_amt_vat_incl                0.914115
# ship_charge_amt_vat_incl                         0.261098
# total_ship_charge_amt_vat_incl                  -0.008318
# total_activity_value_amt_vat_incl                0.912799
#
#                                    total_price_of_items_vat_amt  \
# qty                                                    0.134825
# item_weight                                           -0.042526
# total_activity_weight                                 -0.040208
# price_of_items_amt_vat_excl                            0.882526
# total_price_of_items_amt_vat_excl                      0.882942
# ship_charge_amt_vat_excl                               0.222416
# total_ship_charge_amt_vat_excl                        -0.019970
# total_activity_value_amt_vat_excl                      0.881234
# price_of_items_vat_rate_percent                        0.253462
# price_of_items_vat_amt                                 0.999699
# total_price_of_items_vat_amt                           1.000000
# ship_charge_vat_rate_percent                           0.437944
# ship_charge_vat_amt                                    0.463027
# total_ship_charge_vat_amt                              0.097574
# total_activity_value_vat_amt                           0.999857
# price_of_items_amt_vat_incl                            0.913979
# total_price_of_items_amt_vat_incl                      0.914383
# ship_charge_amt_vat_incl                               0.260325
# total_ship_charge_amt_vat_incl                        -0.008015
# total_activity_value_amt_vat_incl                      0.913074
#
#                                    ship_charge_vat_rate_percent  \
# qty                                                   -0.094448
# item_weight                                            0.012058
# total_activity_weight                                 -0.062470
# price_of_items_amt_vat_excl                           -0.099538
# total_price_of_items_amt_vat_excl                     -0.099382
# ship_charge_amt_vat_excl                               0.043021
# total_ship_charge_amt_vat_excl                        -0.048328
# total_activity_value_amt_vat_excl                     -0.105959
# price_of_items_vat_rate_percent                        1.000000
# price_of_items_vat_amt                                 0.438218
# total_price_of_items_vat_amt                           0.437944
# ship_charge_vat_rate_percent                           1.000000
# ship_charge_vat_amt                                    0.288099
# total_ship_charge_vat_amt                              0.107245
# total_activity_value_vat_amt                           0.437348
# price_of_items_amt_vat_incl                           -0.018522
# total_price_of_items_amt_vat_incl                     -0.018431
# ship_charge_amt_vat_incl                               0.075160
# total_ship_charge_amt_vat_incl                        -0.033235
# total_activity_value_amt_vat_incl                     -0.024424
#
#                                    ship_charge_vat_amt  \
# qty                                          -0.029545
# item_weight                                   0.168079
# total_activity_weight                        -0.018335
# price_of_items_amt_vat_excl                   0.343006
# total_price_of_items_amt_vat_excl             0.341983
# ship_charge_amt_vat_excl                      0.702882
# total_ship_charge_amt_vat_excl                0.373418
# total_activity_value_amt_vat_excl             0.360223
# price_of_items_vat_rate_percent               0.205012
# price_of_items_vat_amt                        0.464068
# total_price_of_items_vat_amt                  0.463027
# ship_charge_vat_rate_percent                  0.288099
# ship_charge_vat_amt                           1.000000
# total_ship_charge_vat_amt                     0.633682
# total_activity_value_vat_amt                  0.481797
# price_of_items_amt_vat_incl                   0.374552
# total_price_of_items_amt_vat_incl             0.373479
# ship_charge_amt_vat_incl                      0.763483
# total_ship_charge_amt_vat_incl                0.415208
# total_activity_value_amt_vat_incl             0.392603
#
#                                    total_ship_charge_vat_amt  \
# qty                                                -0.010877
# item_weight                                         0.018981
# total_activity_weight                              -0.007762
# price_of_items_amt_vat_excl                         0.053600
# total_price_of_items_amt_vat_excl                   0.053922
# ship_charge_amt_vat_excl                            0.464205
# total_ship_charge_amt_vat_excl                      0.631242
# total_activity_value_amt_vat_excl                   0.088236
# price_of_items_vat_rate_percent                     0.077649
# price_of_items_vat_amt                              0.097304
# total_price_of_items_vat_amt                        0.097574
# ship_charge_vat_rate_percent                        0.107245
# ship_charge_vat_amt                                 0.633682
# total_ship_charge_vat_amt                           1.000000
# total_activity_value_vat_amt                        0.131535
# price_of_items_amt_vat_incl                         0.062431
# total_price_of_items_amt_vat_incl                   0.062755
# ship_charge_amt_vat_incl                            0.500876
# total_ship_charge_amt_vat_incl                      0.694173
# total_activity_value_amt_vat_incl                   0.098293
#
#                                    total_activity_value_vat_amt  \
# qty                                                    0.134713
# item_weight                                           -0.042622
# total_activity_weight                                 -0.040305
# price_of_items_amt_vat_excl                            0.882262
# total_price_of_items_amt_vat_excl                      0.882684
# ship_charge_amt_vat_excl                               0.238198
# total_ship_charge_amt_vat_excl                         0.002725
# total_activity_value_amt_vat_excl                      0.881346
# price_of_items_vat_rate_percent                        0.253825
# price_of_items_vat_amt                                 0.999550
# total_price_of_items_vat_amt                           0.999857
# ship_charge_vat_rate_percent                           0.437348
# ship_charge_vat_amt                                    0.481797
# total_ship_charge_vat_amt                              0.131535
# total_activity_value_vat_amt                           1.000000
# price_of_items_amt_vat_incl                            0.913729
# total_price_of_items_amt_vat_incl                      0.914138
# ship_charge_amt_vat_incl                               0.277005
# total_ship_charge_amt_vat_incl                         0.016784
# total_activity_value_amt_vat_incl                      0.913179
#
#                                    price_of_items_amt_vat_incl  \
# qty                                                   0.165275
# item_weight                                          -0.047036
# total_activity_weight                                -0.044038
# price_of_items_amt_vat_excl                           0.997417
# total_price_of_items_amt_vat_excl                     0.997057
# ship_charge_amt_vat_excl                              0.382130
# total_ship_charge_amt_vat_excl                        0.060339
# total_activity_value_amt_vat_excl                     0.996497
# price_of_items_vat_rate_percent                      -0.034929
# price_of_items_vat_amt                                0.914348
# total_price_of_items_vat_amt                          0.913979
# ship_charge_vat_rate_percent                         -0.018522
# ship_charge_vat_amt                                   0.374552
# total_ship_charge_vat_amt                             0.062431
# total_activity_value_vat_amt                          0.913729
# price_of_items_amt_vat_incl                           1.000000
# total_price_of_items_amt_vat_incl                     0.999630
# ship_charge_amt_vat_incl                              0.393343
# total_ship_charge_amt_vat_incl                        0.063349
# total_activity_value_amt_vat_incl                     0.999333
#
#                                    total_price_of_items_amt_vat_incl  \
# qty                                                         0.165262
# item_weight                                                -0.046779
# total_activity_weight                                      -0.043790
# price_of_items_amt_vat_excl                                 0.997027
# total_price_of_items_amt_vat_excl                           0.997417
# ship_charge_amt_vat_excl                                    0.381205
# total_ship_charge_amt_vat_excl                              0.060699
# total_activity_value_amt_vat_excl                           0.996867
# price_of_items_vat_rate_percent                            -0.034680
# price_of_items_vat_amt                                      0.914115
# total_price_of_items_vat_amt                                0.914383
# ship_charge_vat_rate_percent                               -0.018431
# ship_charge_vat_amt                                         0.373479
# total_ship_charge_vat_amt                                   0.062755
# total_activity_value_vat_amt                                0.914138
# price_of_items_amt_vat_incl                                 0.999630
# total_price_of_items_amt_vat_incl                           1.000000
# ship_charge_amt_vat_incl                                    0.392375
# total_ship_charge_amt_vat_incl                              0.063713
# total_activity_value_amt_vat_incl                           0.999712
#
#                                    ship_charge_amt_vat_incl  \
# qty                                               -0.029115
# item_weight                                        0.170649
# total_activity_weight                             -0.017679
# price_of_items_amt_vat_excl                        0.402137
# total_price_of_items_amt_vat_excl                  0.401175
# ship_charge_amt_vat_excl                           0.996020
# total_ship_charge_amt_vat_excl                     0.743762
# total_activity_value_amt_vat_excl                  0.435738
# price_of_items_vat_rate_percent                   -0.094135
# price_of_items_vat_amt                             0.261098
# total_price_of_items_vat_amt                       0.260325
# ship_charge_vat_rate_percent                       0.075160
# ship_charge_vat_amt                                0.763483
# total_ship_charge_vat_amt                          0.500876
# total_activity_value_vat_amt                       0.277005
# price_of_items_amt_vat_incl                        0.393343
# total_price_of_items_amt_vat_incl                  0.392375
# ship_charge_amt_vat_incl                           1.000000
# total_ship_charge_amt_vat_incl                     0.744483
# total_activity_value_amt_vat_incl                  0.425226
#
#                                    total_ship_charge_amt_vat_incl  \
# qty                                                     -0.011326
# item_weight                                              0.032307
# total_activity_weight                                   -0.007708
# price_of_items_amt_vat_excl                              0.072924
# total_price_of_items_amt_vat_excl                        0.073291
# ship_charge_amt_vat_excl                                 0.762715
# total_ship_charge_amt_vat_excl                           0.996464
# total_activity_value_amt_vat_excl                        0.122567
# price_of_items_vat_rate_percent                         -0.120796
# price_of_items_vat_amt                                  -0.008318
# total_price_of_items_vat_amt                            -0.008015
# ship_charge_vat_rate_percent                            -0.033235
# ship_charge_vat_amt                                      0.415208
# total_ship_charge_vat_amt                                0.694173
# total_activity_value_vat_amt                             0.016784
# price_of_items_amt_vat_incl                              0.063349
# total_price_of_items_amt_vat_incl                        0.063713
# ship_charge_amt_vat_incl                                 0.744483
# total_ship_charge_amt_vat_incl                           1.000000
# total_activity_value_amt_vat_incl                        0.110489
#
#                                    total_activity_value_amt_vat_incl
# qty                                                         0.165210
# item_weight                                                -0.046961
# total_activity_weight                                      -0.043971
# price_of_items_amt_vat_excl                                 0.996914
# total_price_of_items_amt_vat_excl                           0.997314
# ship_charge_amt_vat_excl                                    0.415218
# total_ship_charge_amt_vat_excl                              0.107503
# total_activity_value_amt_vat_excl                           0.997386
# price_of_items_vat_rate_percent                            -0.037566
# price_of_items_vat_amt                                      0.912799
# total_price_of_items_vat_amt                                0.913074
# ship_charge_vat_rate_percent                               -0.024424
# ship_charge_vat_amt                                         0.392603
# total_ship_charge_vat_amt                                   0.098293
# total_activity_value_vat_amt                                0.913179
# price_of_items_amt_vat_incl                                 0.999333
# total_price_of_items_amt_vat_incl                           0.999712
# ship_charge_amt_vat_incl                                    0.425226
# total_ship_charge_amt_vat_incl                              0.110489
# total_activity_value_amt_vat_incl                           1.000000

# %%
df_2 = pd.read_excel('amazon_sales_data_2022.xlsx')
df_2
# Out:
#       UNIQUE_ACCOUNT_IDENTIFIER ACTIVITY_PERIOD SALES_CHANNEL   MARKETPLACE  \
# 0                           NaN      2022-01-01           AFN     amazon.it
# 1                           NaN      2022-01-01           AFN     amazon.de
# 2                           NaN      2022-01-01           AFN  amazon.co.uk
# 3                           NaN      2022-01-01           AFN     amazon.de
# 4                           NaN      2022-01-01           AFN     amazon.de
# ...                         ...             ...           ...           ...
# 1910                        NaN      2022-12-01           AFN  amazon.co.uk
# 1911                        NaN      2022-12-01           AFN     amazon.it
# 1912                        NaN      2022-12-01           AFN     amazon.de
# 1913                        NaN      2022-12-01           AFN     amazon.de
# 1914                        NaN      2022-12-01           AFN     amazon.de
#
#      PROGRAM_TYPE  TRANSACTION_TYPE TRANSACTION_EVENT_ID  \
# 0         REGULAR              SALE  402-3774533-8136325
# 1         REGULAR            REFUND  306-6960921-3849155
# 2         REGULAR              SALE  026-6697857-2444326
# 3         REGULAR              SALE  302-1700385-0183531
# 4         REGULAR              SALE  302-1700385-0183531
# ...           ...               ...                  ...
# 1910      REGULAR              SALE  205-5082806-1349932
# 1911      REGULAR              SALE  403-9944514-9532355
# 1912      REGULAR              SALE  304-8490713-7010746
# 1913      REGULAR              SALE  028-3671956-5543558
# 1914  LIQUIDATION  LIQUIDATION_SALE           4sow04Ar4F
#
#                                 ACTIVITY_TRANSACTION_ID TAX_CALCULATION_DATE  \
# 0                                             D3VTVkHNm           30-01-2022
# 1                     amzn1:crow:E0tAm+KlQ0GLDXpCtycBCw           09-10-2021
# 2                                             DCPfZ1C4m           29-01-2022
# 3                                             DGBNmzCBm           29-01-2022
# 4                                             DGBNmzCBm           29-01-2022
# ...                                                 ...                  ...
# 1910                                          DnZp9Dc9f           21-11-2022
# 1911                                          D6gYxWB4f           30-11-2022
# 1912                                          DGxcQ22Qf           30-11-2022
# 1913                                          D1tw5PgCf           01-12-2022
# 1914  10013155200911ReturnIdAndGroupId-10005297186911-0           01-12-2022
#
#      TRANSACTION_DEPART_DATE  ... VAT_INV_EXCHANGE_RATE  \
# 0                 31-01-2022  ...                   NaN
# 1                        NaN  ...                   NaN
# 2                 30-01-2022  ...                   NaN
# 3                 29-01-2022  ...                   NaN
# 4                 29-01-2022  ...                   NaN
# ...                      ...  ...                   ...
# 1910              02-12-2022  ...                   NaN
# 1911              01-12-2022  ...                   NaN
# 1912              01-12-2022  ...                   NaN
# 1913              01-12-2022  ...                   NaN
# 1914              01-12-2022  ...                   NaN
#
#      VAT_INV_EXCHANGE_RATE_DATE EXPORT_OUTSIDE_EU  \
# 0                           NaN                NO
# 1                           NaN                NO
# 2                           NaN                NO
# 3                           NaN                NO
# 4                           NaN                NO
# ...                         ...               ...
# 1910                        NaN               YES
# 1911                        NaN                NO
# 1912                        NaN                NO
# 1913                        NaN                NO
# 1914                        NaN                NO
#
#                                             INVOICE_URL BUYER_NAME  \
# 0     https://www.Amazon.it/gp/invoice/download.html...        NaN
# 1     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 2     https://www.Amazon.co.uk/gp/invoice/download.h...        NaN
# 3     https://www.Amazon.de/gp/invoice/download.html...        NaN
# 4     https://www.Amazon.de/gp/invoice/download.html...        NaN
# ...                                                 ...        ...
# 1910  https://www.Amazon.co.uk/gp/invoice/download.h...        NaN
# 1911                                                NaN        NaN
# 1912  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 1913  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 1914  https://www.Amazon.de/gp/invoice/download.html...        NaN
#
#      ARRIVAL_ADDRESS SUPPLIER_NAME  SUPPLIER_VAT_NUMBER  TAX_REPORTING_SCHEME  \
# 0                NaN           NaN                  NaN               REGULAR
# 1                NaN           NaN                  NaN               REGULAR
# 2                NaN           NaN                  NaN      UK_VOEC-DOMESTIC
# 3                NaN           NaN                  NaN               REGULAR
# 4                NaN           NaN                  NaN               REGULAR
# ...              ...           ...                  ...                   ...
# 1910             NaN           NaN                  NaN        UK_VOEC-IMPORT
# 1911             NaN           NaN                  NaN               REGULAR
# 1912             NaN           NaN                  NaN               REGULAR
# 1913             NaN           NaN                  NaN               REGULAR
# 1914             NaN           NaN                  NaN               REGULAR
#
#       TAX_COLLECTION_RESPONSIBILITY
# 0                            SELLER
# 1                            SELLER
# 2                       MARKETPLACE
# 3                            SELLER
# 4                            SELLER
# ...                             ...
# 1910                    MARKETPLACE
# 1911                         SELLER
# 1912                         SELLER
# 1913                         SELLER
# 1914                         SELLER
#
# [1915 rows x 97 columns]

# %%
df_2.head()
# Out:
#    UNIQUE_ACCOUNT_IDENTIFIER ACTIVITY_PERIOD SALES_CHANNEL   MARKETPLACE  \
# 0                        NaN      2022-01-01           AFN     amazon.it
# 1                        NaN      2022-01-01           AFN     amazon.de
# 2                        NaN      2022-01-01           AFN  amazon.co.uk
# 3                        NaN      2022-01-01           AFN     amazon.de
# 4                        NaN      2022-01-01           AFN     amazon.de
#
#   PROGRAM_TYPE TRANSACTION_TYPE TRANSACTION_EVENT_ID  \
# 0      REGULAR             SALE  402-3774533-8136325
# 1      REGULAR           REFUND  306-6960921-3849155
# 2      REGULAR             SALE  026-6697857-2444326
# 3      REGULAR             SALE  302-1700385-0183531
# 4      REGULAR             SALE  302-1700385-0183531
#
#              ACTIVITY_TRANSACTION_ID TAX_CALCULATION_DATE  \
# 0                          D3VTVkHNm           30-01-2022
# 1  amzn1:crow:E0tAm+KlQ0GLDXpCtycBCw           09-10-2021
# 2                          DCPfZ1C4m           29-01-2022
# 3                          DGBNmzCBm           29-01-2022
# 4                          DGBNmzCBm           29-01-2022
#
#   TRANSACTION_DEPART_DATE  ... VAT_INV_EXCHANGE_RATE  \
# 0              31-01-2022  ...                   NaN
# 1                     NaN  ...                   NaN
# 2              30-01-2022  ...                   NaN
# 3              29-01-2022  ...                   NaN
# 4              29-01-2022  ...                   NaN
#
#   VAT_INV_EXCHANGE_RATE_DATE EXPORT_OUTSIDE_EU  \
# 0                        NaN                NO
# 1                        NaN                NO
# 2                        NaN                NO
# 3                        NaN                NO
# 4                        NaN                NO
#
#                                          INVOICE_URL BUYER_NAME  \
# 0  https://www.Amazon.it/gp/invoice/download.html...        NaN
# 1  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 2  https://www.Amazon.co.uk/gp/invoice/download.h...        NaN
# 3  https://www.Amazon.de/gp/invoice/download.html...        NaN
# 4  https://www.Amazon.de/gp/invoice/download.html...        NaN
#
#   ARRIVAL_ADDRESS SUPPLIER_NAME  SUPPLIER_VAT_NUMBER  TAX_REPORTING_SCHEME  \
# 0             NaN           NaN                  NaN               REGULAR
# 1             NaN           NaN                  NaN               REGULAR
# 2             NaN           NaN                  NaN      UK_VOEC-DOMESTIC
# 3             NaN           NaN                  NaN               REGULAR
# 4             NaN           NaN                  NaN               REGULAR
#
#    TAX_COLLECTION_RESPONSIBILITY
# 0                         SELLER
# 1                         SELLER
# 2                    MARKETPLACE
# 3                         SELLER
# 4                         SELLER
#
# [5 rows x 97 columns]

# %%
df.columns.unique()
# Out:
# Index(['activity_period', 'marketplace', 'transaction_type', 'asin',
#        'product_name', 'product_type', 'qty', 'item_weight',
#        'total_activity_weight', 'price_of_items_amt_vat_excl',
#        'total_price_of_items_amt_vat_excl', 'ship_charge_amt_vat_excl',
#        'total_ship_charge_amt_vat_excl', 'total_activity_value_amt_vat_excl',
#        'price_of_items_vat_rate_percent', 'price_of_items_vat_amt',
#        'total_price_of_items_vat_amt', 'ship_charge_vat_rate_percent',
#        'ship_charge_vat_amt', 'total_ship_charge_vat_amt',
#        'total_activity_value_vat_amt', 'price_of_items_amt_vat_incl',
#        'total_price_of_items_amt_vat_incl', 'ship_charge_amt_vat_incl',
#        'total_ship_charge_amt_vat_incl', 'total_activity_value_amt_vat_incl',
#        'transaction_currency_code', 'depature_city', 'departure_country',
#        'departure_post_code', 'arrival_city', 'arrival_country',
#        'arrival_post_code', 'sale_depart_country', 'sale_arrival_country',
#        'transportation_mode', 'delivery_conditions', 'taxable_jurisdiction',
#        'export_outside_eu', 'tax_reporting_scheme',
#        'tax_collection_responsibility'],
#       dtype='object')

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      activity_period marketplace transaction_type        asin  \
# 0         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 1         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 2         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 3         2020-03-01   amazon.de             SALE  B083LZ1GJD
# 4         2020-03-01   amazon.de             SALE  B083LZ1GJD
# ...              ...         ...              ...         ...
# 7618      2021-12-01   amazon.it           REFUND  B082J64726
# 7619      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7620      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7621      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
# 7622      2021-12-01         NaN      FC_TRANSFER  B0982CT8BH
#
#                                 product_name product_type  qty  item_weight  \
# 0     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 1     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 2     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 3     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    1         0.55
# 4     Eco Roll Clear - Waschbare Fusselrolle     Eco Roll    2         0.55
# ...                                      ...          ...  ...          ...
# 7618                Immersion Heater 3.000 W           3K    1          NaN
# 7619               Baby Carrier (Lilac Grey)   Lilac Grey   14         0.87
# 7620               Baby Carrier (Lilac Grey)   Lilac Grey    2         0.87
# 7621               Baby Carrier (Lilac Grey)   Lilac Grey    9         0.87
# 7622               Baby Carrier (Lilac Grey)   Lilac Grey    3         0.87
#
#       total_activity_weight  price_of_items_amt_vat_excl  ...  \
# 0                      0.55                        12.60  ...
# 1                      0.55                        12.60  ...
# 2                      0.55                        12.60  ...
# 3                      0.55                        16.80  ...
# 4                      1.10                        25.20  ...
# ...                     ...                          ...  ...
# 7618                    NaN                       -84.03  ...
# 7619                  12.18                          NaN  ...
# 7620                   1.74                          NaN  ...
# 7621                   7.83                          NaN  ...
# 7622                   2.61                          NaN  ...
#
#       arrival_country  arrival_post_code  sale_depart_country  \
# 0                  DE              30900                   DE
# 1                  DE              79761                   DE
# 2                  DE              14469                   DE
# 3                  DE              02794                   DE
# 4                  DE              89312                   DE
# ...               ...                ...                  ...
# 7618              NaN              76125                   DE
# 7619               FR              57685                  NaN
# 7620               FR              57685                  NaN
# 7621               FR              59553                  NaN
# 7622               FR              59553                  NaN
#
#       sale_arrival_country  transportation_mode  delivery_conditions  \
# 0                       DE  CONSIGNMENT_BY_POST                  DAP
# 1                       DE  CONSIGNMENT_BY_POST                  DAP
# 2                       DE  CONSIGNMENT_BY_POST                  DAP
# 3                       DE  CONSIGNMENT_BY_POST                  DAP
# 4                       DE  CONSIGNMENT_BY_POST                  DAP
# ...                    ...                  ...                  ...
# 7618                    IT  CONSIGNMENT_BY_POST                  DAP
# 7619                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7620                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7621                   NaN    TRANSPORT_BY_ROAD                  XXX
# 7622                   NaN    TRANSPORT_BY_ROAD                  XXX
#
#       taxable_jurisdiction  export_outside_eu  tax_reporting_scheme  \
# 0                  GERMANY                 NO                   NaN
# 1                  GERMANY                 NO                   NaN
# 2                  GERMANY                 NO                   NaN
# 3                  GERMANY                 NO                   NaN
# 4                  GERMANY                 NO                   NaN
# ...                    ...                ...                   ...
# 7618               GERMANY                 NO               REGULAR
# 7619                   NaN                NaN                   NaN
# 7620                   NaN                NaN                   NaN
# 7621                   NaN                NaN                   NaN
# 7622                   NaN                NaN                   NaN
#
#       tax_collection_responsibility
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 7618                         SELLER
# 7619                            NaN
# 7620                            NaN
# 7621                            NaN
# 7622                            NaN
#
# [7623 rows x 41 columns]>

# %%
df_2 = df_2.drop(columns=['UNIQUE_ACCOUNT_IDENTIFIER', 'SALES_CHANNEL', 'PROGRAM_TYPE', 'TRANSACTION_EVENT_ID', 'ACTIVITY_TRANSACTION_ID', 'SELLER_SKU', 'ITEM_MANUFACTURE_COUNTRY','COMMODITY_CODE',
       'STATISTICAL_CODE_DEPART', 'STATISTICAL_CODE_ARRIVAL', 'COST_PRICE_OF_ITEMS', 'PROMO_GIFT_WRAP_AMT_VAT_EXCL', ''
       'COMMODITY_CODE_SUPPLEMENTARY_UNIT', 'ITEM_QTY_SUPPLEMENTARY_UNIT',
       'TOTAL_ACTIVITY_SUPPLEMENTARY_UNIT', 'PRODUCT_TAX_CODE',
       'BUYER_VAT_NUMBER', 'VAT_INV_NUMBER', 'TAXABLE_JURISDICTION_LEVEL', 'INVOICE_URL', 'BUYER_NAME', 'ARRIVAL_ADDRESS', 'SUPPLIER_NAME', 'SUPPLIER_VAT_NUMBER',
       'VAT_INV_CONVERTED_AMT', 'VAT_INV_CURRENCY_CODE',
       'VAT_INV_EXCHANGE_RATE', 'VAT_INV_EXCHANGE_RATE_DATE', 'ITEM_DESCRIPTION', 'TAX_CALCULATION_DATE', 'TRANSACTION_DEPART_DATE',
       'TRANSACTION_ARRIVAL_DATE', 'TRANSACTION_COMPLETE_DATE', 'PROMO_SHIP_CHARGE_AMT_VAT_EXCL', 'PROMO_PRICE_OF_ITEMS_AMT_VAT_EXCL', 'PROMO_PRICE_OF_ITEMS_VAT_AMT', 'PROMO_SHIP_CHARGE_VAT_AMT', 'PROMO_GIFT_WRAP_VAT_AMT', 'PROMO_PRICE_OF_ITEMS_AMT_VAT_INCL', 'PROMO_SHIP_CHARGE_AMT_VAT_INCL', 'PROMO_GIFT_WRAP_AMT_VAT_INCL',
    'GIFT_WRAP_AMT_VAT_EXCL', 'TOTAL_GIFT_WRAP_AMT_VAT_EXCL', 'GIFT_WRAP_VAT_RATE_PERCENT', 'GIFT_WRAP_VAT_AMT', 'TOTAL_GIFT_WRAP_VAT_AMT', 'GIFT_WRAP_AMT_VAT_INCL', 'TOTAL_GIFT_WRAP_AMT_VAT_INCL', 'SELLER_DEPART_VAT_NUMBER_COUNTRY',
       'SELLER_DEPART_COUNTRY_VAT_NUMBER', 'SELLER_ARRIVAL_VAT_NUMBER_COUNTRY',
       'SELLER_ARRIVAL_COUNTRY_VAT_NUMBER',
       'TRANSACTION_SELLER_VAT_NUMBER_COUNTRY',
       'TRANSACTION_SELLER_VAT_NUMBER', 'BUYER_VAT_NUMBER_COUNTRY', 'VAT_CALCULATION_IMPUTATION_COUNTRY'])
df_2
# Out:
#      ACTIVITY_PERIOD   MARKETPLACE  TRANSACTION_TYPE        ASIN  \
# 0         2022-01-01     amazon.it              SALE  B08L3ZJ7QG
# 1         2022-01-01     amazon.de            REFUND  B08GSNC3SG
# 2         2022-01-01  amazon.co.uk              SALE  B08L3ZJ7QG
# 3         2022-01-01     amazon.de              SALE  B08L3ZJ7QG
# 4         2022-01-01     amazon.de              SALE  B08L3Z9SSD
# ...              ...           ...               ...         ...
# 1910      2022-12-01  amazon.co.uk              SALE  B08L3Z9SSD
# 1911      2022-12-01     amazon.it              SALE  B08L3ZJ7QG
# 1912      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1913      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1914      2022-12-01     amazon.de  LIQUIDATION_SALE  B09TTRRHW8
#
#                    Product_Name Product_Type  QTY  ITEM_WEIGHT  \
# 0       Wine Bottle Stand (Red)          Red    1         0.04
# 1      Immersion Heater 1.500 W         1.5K    1          NaN
# 2       Wine Bottle Stand (Red)          Red    1         0.04
# 3       Wine Bottle Stand (Red)          Red    1         0.04
# 4     Wine Bottle Stand (Topas)        Topas    1         0.04
# ...                         ...          ...  ...          ...
# 1910  Wine Bottle Stand (Topas)        Topas    2         0.04
# 1911    Wine Bottle Stand (Red)          Red    1         0.04
# 1912  Wine Bottle Stand (Topas)        Topas    1         0.04
# 1913  Wine Bottle Stand (Topas)        Topas    1         0.04
# 1914   Immersion Heater 3.000 W           3K    1      1570.00
#
#       TOTAL_ACTIVITY_WEIGHT  PRICE_OF_ITEMS_AMT_VAT_EXCL  ...  \
# 0                      0.04                        19.99  ...
# 1                       NaN                       -50.41  ...
# 2                      0.04                        12.49  ...
# 3                      0.04                        12.60  ...
# 4                      0.04                        11.76  ...
# ...                     ...                          ...  ...
# 1910                   0.08                        18.46  ...
# 1911                   0.04                        19.99  ...
# 1912                   0.04                        11.76  ...
# 1913                   0.04                        11.76  ...
# 1914                1570.00                         1.47  ...
#
#       ARRIVAL_COUNTRY  ARRIVAL_POST_CODE  SALE_DEPART_COUNTRY  \
# 0                  IT              20099                   ES
# 1                 NaN              72144                   DE
# 2                  GB           PO12 4HT                   GB
# 3                  DE              40233                   DE
# 4                  DE              40233                   DE
# ...               ...                ...                  ...
# 1910               GB           RG19 4FB                   IT
# 1911               IT              10090                   IT
# 1912               DE              90429                   DE
# 1913               DE              81925                   DE
# 1914               CZ              25301                   FR
#
#       SALE_ARRIVAL_COUNTRY  TRANSPORTATION_MODE  DELIVERY_CONDITIONS  \
# 0                       IT  CONSIGNMENT_BY_POST                  DAP
# 1                       DE  CONSIGNMENT_BY_POST                  DAP
# 2                       GB  CONSIGNMENT_BY_POST                  DAP
# 3                       DE  CONSIGNMENT_BY_POST                  DAP
# 4                       DE  CONSIGNMENT_BY_POST                  DAP
# ...                    ...                  ...                  ...
# 1910                    GB  CONSIGNMENT_BY_POST                  DAP
# 1911                    IT  CONSIGNMENT_BY_POST                  DAP
# 1912                    DE  CONSIGNMENT_BY_POST                  DAP
# 1913                    DE  CONSIGNMENT_BY_POST                  DAP
# 1914                    CZ  CONSIGNMENT_BY_POST                  DAP
#
#       TAXABLE_JURISDICTION  EXPORT_OUTSIDE_EU  TAX_REPORTING_SCHEME  \
# 0                    ITALY                 NO               REGULAR
# 1                  GERMANY                 NO               REGULAR
# 2           UNITED KINGDOM                 NO      UK_VOEC-DOMESTIC
# 3                  GERMANY                 NO               REGULAR
# 4                  GERMANY                 NO               REGULAR
# ...                    ...                ...                   ...
# 1910                 ITALY                YES        UK_VOEC-IMPORT
# 1911                 ITALY                 NO               REGULAR
# 1912               GERMANY                 NO               REGULAR
# 1913               GERMANY                 NO               REGULAR
# 1914                FRANCE                 NO               REGULAR
#
#       TAX_COLLECTION_RESPONSIBILITY
# 0                            SELLER
# 1                            SELLER
# 2                       MARKETPLACE
# 3                            SELLER
# 4                            SELLER
# ...                             ...
# 1910                    MARKETPLACE
# 1911                         SELLER
# 1912                         SELLER
# 1913                         SELLER
# 1914                         SELLER
#
# [1915 rows x 41 columns]

# %%
df_2.fillna('NaN')
# Out:
#      ACTIVITY_PERIOD   MARKETPLACE  TRANSACTION_TYPE        ASIN  \
# 0         2022-01-01     amazon.it              SALE  B08L3ZJ7QG
# 1         2022-01-01     amazon.de            REFUND  B08GSNC3SG
# 2         2022-01-01  amazon.co.uk              SALE  B08L3ZJ7QG
# 3         2022-01-01     amazon.de              SALE  B08L3ZJ7QG
# 4         2022-01-01     amazon.de              SALE  B08L3Z9SSD
# ...              ...           ...               ...         ...
# 1910      2022-12-01  amazon.co.uk              SALE  B08L3Z9SSD
# 1911      2022-12-01     amazon.it              SALE  B08L3ZJ7QG
# 1912      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1913      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1914      2022-12-01     amazon.de  LIQUIDATION_SALE  B09TTRRHW8
#
#                    Product_Name Product_Type  QTY ITEM_WEIGHT  \
# 0       Wine Bottle Stand (Red)          Red    1        0.04
# 1      Immersion Heater 1.500 W         1.5K    1         NaN
# 2       Wine Bottle Stand (Red)          Red    1        0.04
# 3       Wine Bottle Stand (Red)          Red    1        0.04
# 4     Wine Bottle Stand (Topas)        Topas    1        0.04
# ...                         ...          ...  ...         ...
# 1910  Wine Bottle Stand (Topas)        Topas    2        0.04
# 1911    Wine Bottle Stand (Red)          Red    1        0.04
# 1912  Wine Bottle Stand (Topas)        Topas    1        0.04
# 1913  Wine Bottle Stand (Topas)        Topas    1        0.04
# 1914   Immersion Heater 3.000 W           3K    1      1570.0
#
#      TOTAL_ACTIVITY_WEIGHT PRICE_OF_ITEMS_AMT_VAT_EXCL  ... ARRIVAL_COUNTRY  \
# 0                     0.04                       19.99  ...              IT
# 1                      NaN                      -50.41  ...             NaN
# 2                     0.04                       12.49  ...              GB
# 3                     0.04                        12.6  ...              DE
# 4                     0.04                       11.76  ...              DE
# ...                    ...                         ...  ...             ...
# 1910                  0.08                       18.46  ...              GB
# 1911                  0.04                       19.99  ...              IT
# 1912                  0.04                       11.76  ...              DE
# 1913                  0.04                       11.76  ...              DE
# 1914                1570.0                        1.47  ...              CZ
#
#      ARRIVAL_POST_CODE SALE_DEPART_COUNTRY SALE_ARRIVAL_COUNTRY  \
# 0                20099                  ES                   IT
# 1                72144                  DE                   DE
# 2             PO12 4HT                  GB                   GB
# 3                40233                  DE                   DE
# 4                40233                  DE                   DE
# ...                ...                 ...                  ...
# 1910          RG19 4FB                  IT                   GB
# 1911             10090                  IT                   IT
# 1912             90429                  DE                   DE
# 1913             81925                  DE                   DE
# 1914             25301                  FR                   CZ
#
#       TRANSPORTATION_MODE DELIVERY_CONDITIONS TAXABLE_JURISDICTION  \
# 0     CONSIGNMENT_BY_POST                 DAP                ITALY
# 1     CONSIGNMENT_BY_POST                 DAP              GERMANY
# 2     CONSIGNMENT_BY_POST                 DAP       UNITED KINGDOM
# 3     CONSIGNMENT_BY_POST                 DAP              GERMANY
# 4     CONSIGNMENT_BY_POST                 DAP              GERMANY
# ...                   ...                 ...                  ...
# 1910  CONSIGNMENT_BY_POST                 DAP                ITALY
# 1911  CONSIGNMENT_BY_POST                 DAP                ITALY
# 1912  CONSIGNMENT_BY_POST                 DAP              GERMANY
# 1913  CONSIGNMENT_BY_POST                 DAP              GERMANY
# 1914  CONSIGNMENT_BY_POST                 DAP               FRANCE
#
#      EXPORT_OUTSIDE_EU TAX_REPORTING_SCHEME TAX_COLLECTION_RESPONSIBILITY
# 0                   NO              REGULAR                        SELLER
# 1                   NO              REGULAR                        SELLER
# 2                   NO     UK_VOEC-DOMESTIC                   MARKETPLACE
# 3                   NO              REGULAR                        SELLER
# 4                   NO              REGULAR                        SELLER
# ...                ...                  ...                           ...
# 1910               YES       UK_VOEC-IMPORT                   MARKETPLACE
# 1911                NO              REGULAR                        SELLER
# 1912                NO              REGULAR                        SELLER
# 1913                NO              REGULAR                        SELLER
# 1914                NO              REGULAR                        SELLER
#
# [1915 rows x 41 columns]

# %%
df_2.reset_index(drop=True)
# Out:
#      ACTIVITY_PERIOD   MARKETPLACE  TRANSACTION_TYPE        ASIN  \
# 0         2022-01-01     amazon.it              SALE  B08L3ZJ7QG
# 1         2022-01-01     amazon.de            REFUND  B08GSNC3SG
# 2         2022-01-01  amazon.co.uk              SALE  B08L3ZJ7QG
# 3         2022-01-01     amazon.de              SALE  B08L3ZJ7QG
# 4         2022-01-01     amazon.de              SALE  B08L3Z9SSD
# ...              ...           ...               ...         ...
# 1910      2022-12-01  amazon.co.uk              SALE  B08L3Z9SSD
# 1911      2022-12-01     amazon.it              SALE  B08L3ZJ7QG
# 1912      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1913      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1914      2022-12-01     amazon.de  LIQUIDATION_SALE  B09TTRRHW8
#
#                    Product_Name Product_Type  QTY  ITEM_WEIGHT  \
# 0       Wine Bottle Stand (Red)          Red    1         0.04
# 1      Immersion Heater 1.500 W         1.5K    1          NaN
# 2       Wine Bottle Stand (Red)          Red    1         0.04
# 3       Wine Bottle Stand (Red)          Red    1         0.04
# 4     Wine Bottle Stand (Topas)        Topas    1         0.04
# ...                         ...          ...  ...          ...
# 1910  Wine Bottle Stand (Topas)        Topas    2         0.04
# 1911    Wine Bottle Stand (Red)          Red    1         0.04
# 1912  Wine Bottle Stand (Topas)        Topas    1         0.04
# 1913  Wine Bottle Stand (Topas)        Topas    1         0.04
# 1914   Immersion Heater 3.000 W           3K    1      1570.00
#
#       TOTAL_ACTIVITY_WEIGHT  PRICE_OF_ITEMS_AMT_VAT_EXCL  ...  \
# 0                      0.04                        19.99  ...
# 1                       NaN                       -50.41  ...
# 2                      0.04                        12.49  ...
# 3                      0.04                        12.60  ...
# 4                      0.04                        11.76  ...
# ...                     ...                          ...  ...
# 1910                   0.08                        18.46  ...
# 1911                   0.04                        19.99  ...
# 1912                   0.04                        11.76  ...
# 1913                   0.04                        11.76  ...
# 1914                1570.00                         1.47  ...
#
#       ARRIVAL_COUNTRY  ARRIVAL_POST_CODE  SALE_DEPART_COUNTRY  \
# 0                  IT              20099                   ES
# 1                 NaN              72144                   DE
# 2                  GB           PO12 4HT                   GB
# 3                  DE              40233                   DE
# 4                  DE              40233                   DE
# ...               ...                ...                  ...
# 1910               GB           RG19 4FB                   IT
# 1911               IT              10090                   IT
# 1912               DE              90429                   DE
# 1913               DE              81925                   DE
# 1914               CZ              25301                   FR
#
#       SALE_ARRIVAL_COUNTRY  TRANSPORTATION_MODE  DELIVERY_CONDITIONS  \
# 0                       IT  CONSIGNMENT_BY_POST                  DAP
# 1                       DE  CONSIGNMENT_BY_POST                  DAP
# 2                       GB  CONSIGNMENT_BY_POST                  DAP
# 3                       DE  CONSIGNMENT_BY_POST                  DAP
# 4                       DE  CONSIGNMENT_BY_POST                  DAP
# ...                    ...                  ...                  ...
# 1910                    GB  CONSIGNMENT_BY_POST                  DAP
# 1911                    IT  CONSIGNMENT_BY_POST                  DAP
# 1912                    DE  CONSIGNMENT_BY_POST                  DAP
# 1913                    DE  CONSIGNMENT_BY_POST                  DAP
# 1914                    CZ  CONSIGNMENT_BY_POST                  DAP
#
#       TAXABLE_JURISDICTION  EXPORT_OUTSIDE_EU  TAX_REPORTING_SCHEME  \
# 0                    ITALY                 NO               REGULAR
# 1                  GERMANY                 NO               REGULAR
# 2           UNITED KINGDOM                 NO      UK_VOEC-DOMESTIC
# 3                  GERMANY                 NO               REGULAR
# 4                  GERMANY                 NO               REGULAR
# ...                    ...                ...                   ...
# 1910                 ITALY                YES        UK_VOEC-IMPORT
# 1911                 ITALY                 NO               REGULAR
# 1912               GERMANY                 NO               REGULAR
# 1913               GERMANY                 NO               REGULAR
# 1914                FRANCE                 NO               REGULAR
#
#       TAX_COLLECTION_RESPONSIBILITY
# 0                            SELLER
# 1                            SELLER
# 2                       MARKETPLACE
# 3                            SELLER
# 4                            SELLER
# ...                             ...
# 1910                    MARKETPLACE
# 1911                         SELLER
# 1912                         SELLER
# 1913                         SELLER
# 1914                         SELLER
#
# [1915 rows x 41 columns]

# %%
def lower_case_column_names(columns):
    df_2.columns = [i.lower() for i in df_2.columns]
    return df_2

# %%
lower_case_column_names(df_2)
# Out:
#      activity_period   marketplace  transaction_type        asin  \
# 0         2022-01-01     amazon.it              SALE  B08L3ZJ7QG
# 1         2022-01-01     amazon.de            REFUND  B08GSNC3SG
# 2         2022-01-01  amazon.co.uk              SALE  B08L3ZJ7QG
# 3         2022-01-01     amazon.de              SALE  B08L3ZJ7QG
# 4         2022-01-01     amazon.de              SALE  B08L3Z9SSD
# ...              ...           ...               ...         ...
# 1910      2022-12-01  amazon.co.uk              SALE  B08L3Z9SSD
# 1911      2022-12-01     amazon.it              SALE  B08L3ZJ7QG
# 1912      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1913      2022-12-01     amazon.de              SALE  B08L3Z9SSD
# 1914      2022-12-01     amazon.de  LIQUIDATION_SALE  B09TTRRHW8
#
#                    product_name product_type  qty  item_weight  \
# 0       Wine Bottle Stand (Red)          Red    1         0.04
# 1      Immersion Heater 1.500 W         1.5K    1          NaN
# 2       Wine Bottle Stand (Red)          Red    1         0.04
# 3       Wine Bottle Stand (Red)          Red    1         0.04
# 4     Wine Bottle Stand (Topas)        Topas    1         0.04
# ...                         ...          ...  ...          ...
# 1910  Wine Bottle Stand (Topas)        Topas    2         0.04
# 1911    Wine Bottle Stand (Red)          Red    1         0.04
# 1912  Wine Bottle Stand (Topas)        Topas    1         0.04
# 1913  Wine Bottle Stand (Topas)        Topas    1         0.04
# 1914   Immersion Heater 3.000 W           3K    1      1570.00
#
#       total_activity_weight  price_of_items_amt_vat_excl  ...  \
# 0                      0.04                        19.99  ...
# 1                       NaN                       -50.41  ...
# 2                      0.04                        12.49  ...
# 3                      0.04                        12.60  ...
# 4                      0.04                        11.76  ...
# ...                     ...                          ...  ...
# 1910                   0.08                        18.46  ...
# 1911                   0.04                        19.99  ...
# 1912                   0.04                        11.76  ...
# 1913                   0.04                        11.76  ...
# 1914                1570.00                         1.47  ...
#
#       arrival_country  arrival_post_code  sale_depart_country  \
# 0                  IT              20099                   ES
# 1                 NaN              72144                   DE
# 2                  GB           PO12 4HT                   GB
# 3                  DE              40233                   DE
# 4                  DE              40233                   DE
# ...               ...                ...                  ...
# 1910               GB           RG19 4FB                   IT
# 1911               IT              10090                   IT
# 1912               DE              90429                   DE
# 1913               DE              81925                   DE
# 1914               CZ              25301                   FR
#
#       sale_arrival_country  transportation_mode  delivery_conditions  \
# 0                       IT  CONSIGNMENT_BY_POST                  DAP
# 1                       DE  CONSIGNMENT_BY_POST                  DAP
# 2                       GB  CONSIGNMENT_BY_POST                  DAP
# 3                       DE  CONSIGNMENT_BY_POST                  DAP
# 4                       DE  CONSIGNMENT_BY_POST                  DAP
# ...                    ...                  ...                  ...
# 1910                    GB  CONSIGNMENT_BY_POST                  DAP
# 1911                    IT  CONSIGNMENT_BY_POST                  DAP
# 1912                    DE  CONSIGNMENT_BY_POST                  DAP
# 1913                    DE  CONSIGNMENT_BY_POST                  DAP
# 1914                    CZ  CONSIGNMENT_BY_POST                  DAP
#
#       taxable_jurisdiction  export_outside_eu  tax_reporting_scheme  \
# 0                    ITALY                 NO               REGULAR
# 1                  GERMANY                 NO               REGULAR
# 2           UNITED KINGDOM                 NO      UK_VOEC-DOMESTIC
# 3                  GERMANY                 NO               REGULAR
# 4                  GERMANY                 NO               REGULAR
# ...                    ...                ...                   ...
# 1910                 ITALY                YES        UK_VOEC-IMPORT
# 1911                 ITALY                 NO               REGULAR
# 1912               GERMANY                 NO               REGULAR
# 1913               GERMANY                 NO               REGULAR
# 1914                FRANCE                 NO               REGULAR
#
#       tax_collection_responsibility
# 0                            SELLER
# 1                            SELLER
# 2                       MARKETPLACE
# 3                            SELLER
# 4                            SELLER
# ...                             ...
# 1910                    MARKETPLACE
# 1911                         SELLER
# 1912                         SELLER
# 1913                         SELLER
# 1914                         SELLER
#
# [1915 rows x 41 columns]

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1915 entries, 0 to 1914
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   activity_period                    1915 non-null   datetime64[ns]
#  1   marketplace                        1785 non-null   object
#  2   transaction_type                   1915 non-null   object
#  3   asin                               1915 non-null   object
#  4   product_name                       1915 non-null   object
#  5   product_type                       1915 non-null   object
#  6   qty                                1915 non-null   int64
#  7   item_weight                        1792 non-null   float64
#  8   total_activity_weight              1791 non-null   float64
#  9   price_of_items_amt_vat_excl        1653 non-null   float64
#  10  total_price_of_items_amt_vat_excl  1653 non-null   float64
#  11  ship_charge_amt_vat_excl           1413 non-null   float64
#  12  total_ship_charge_amt_vat_excl     1413 non-null   float64
#  13  total_activity_value_amt_vat_excl  1654 non-null   float64
#  14  price_of_items_vat_rate_percent    1653 non-null   float64
#  15  price_of_items_vat_amt             1653 non-null   float64
#  16  total_price_of_items_vat_amt       1653 non-null   float64
#  17  ship_charge_vat_rate_percent       1413 non-null   float64
#  18  ship_charge_vat_amt                1413 non-null   float64
#  19  total_ship_charge_vat_amt          1413 non-null   float64
#  20  total_activity_value_vat_amt       1654 non-null   float64
#  21  price_of_items_amt_vat_incl        1687 non-null   float64
#  22  total_price_of_items_amt_vat_incl  1687 non-null   float64
#  23  ship_charge_amt_vat_incl           1447 non-null   float64
#  24  total_ship_charge_amt_vat_incl     1447 non-null   float64
#  25  total_activity_value_amt_vat_incl  1688 non-null   float64
#  26  transaction_currency_code          1688 non-null   object
#  27  depature_city                      1915 non-null   object
#  28  departure_country                  1803 non-null   object
#  29  departure_post_code                1915 non-null   object
#  30  arrival_city                       1915 non-null   object
#  31  arrival_country                    1803 non-null   object
#  32  arrival_post_code                  1915 non-null   object
#  33  sale_depart_country                1785 non-null   object
#  34  sale_arrival_country               1785 non-null   object
#  35  transportation_mode                1881 non-null   object
#  36  delivery_conditions                1881 non-null   object
#  37  taxable_jurisdiction               1654 non-null   object
#  38  export_outside_eu                  1654 non-null   object
#  39  tax_reporting_scheme               1688 non-null   object
#  40  tax_collection_responsibility      1688 non-null   object
# dtypes: datetime64[ns](1), float64(19), int64(1), object(20)
# memory usage: 613.5+ KB

# %%
df_2.to_excel('clean_amazon_sales_.xlsx')

# %%
df_2_corr = df_2.corr()
df_2_corr
# Out:
# C:\Users\Serhat\AppData\Local\Temp\ipykernel_18204\1959595485.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_2_corr = df_2.corr()
#                                         qty  item_weight  \
# qty                                1.000000    -0.008735
# item_weight                       -0.008735     1.000000
# total_activity_weight             -0.006993     0.999989
# price_of_items_amt_vat_excl        0.177489    -0.075543
# total_price_of_items_amt_vat_excl  0.179301    -0.075137
# ship_charge_amt_vat_excl          -0.017707     0.128073
# total_ship_charge_amt_vat_excl    -0.012687     0.036320
# total_activity_value_amt_vat_excl  0.179076    -0.075527
# price_of_items_vat_rate_percent   -0.008806    -0.153740
# price_of_items_vat_amt             0.152205    -0.093239
# total_price_of_items_vat_amt       0.154923    -0.093042
# ship_charge_vat_rate_percent      -0.092940     0.300472
# ship_charge_vat_amt               -0.014751     0.174301
# total_ship_charge_vat_amt         -0.008721    -0.017129
# total_activity_value_vat_amt       0.154959    -0.093219
# price_of_items_amt_vat_incl        0.182698    -0.078819
# total_price_of_items_amt_vat_incl  0.184765    -0.078444
# ship_charge_amt_vat_incl          -0.017530     0.138090
# total_ship_charge_amt_vat_incl    -0.012574     0.034568
# total_activity_value_amt_vat_incl  0.184610    -0.078836
#
#                                    total_activity_weight  \
# qty                                            -0.006993
# item_weight                                     0.999989
# total_activity_weight                           1.000000
# price_of_items_amt_vat_excl                    -0.074775
# total_price_of_items_amt_vat_excl              -0.074365
# ship_charge_amt_vat_excl                        0.080461
# total_ship_charge_amt_vat_excl                  0.010308
# total_activity_value_amt_vat_excl              -0.074756
# price_of_items_vat_rate_percent                -0.153582
# price_of_items_vat_amt                         -0.092377
# total_price_of_items_vat_amt                   -0.092170
# ship_charge_vat_rate_percent                    0.134846
# ship_charge_vat_amt                             0.133923
# total_ship_charge_vat_amt                      -0.017385
# total_activity_value_vat_amt                   -0.092347
# price_of_items_amt_vat_incl                    -0.078002
# total_price_of_items_amt_vat_incl              -0.077623
# ship_charge_amt_vat_incl                        0.089982
# total_ship_charge_amt_vat_incl                  0.009543
# total_activity_value_amt_vat_incl              -0.078015
#
#                                    price_of_items_amt_vat_excl  \
# qty                                                   0.177489
# item_weight                                          -0.075543
# total_activity_weight                                -0.074775
# price_of_items_amt_vat_excl                           1.000000
# total_price_of_items_amt_vat_excl                     0.998960
# ship_charge_amt_vat_excl                              0.127668
# total_ship_charge_amt_vat_excl                        0.032804
# total_activity_value_amt_vat_excl                     0.998725
# price_of_items_vat_rate_percent                       0.123266
# price_of_items_vat_amt                                0.680358
# total_price_of_items_vat_amt                          0.678783
# ship_charge_vat_rate_percent                          0.158369
# ship_charge_vat_amt                                   0.174528
# total_ship_charge_vat_amt                             0.016773
# total_activity_value_vat_amt                          0.678641
# price_of_items_amt_vat_incl                           0.995489
# total_price_of_items_amt_vat_incl                     0.994882
# ship_charge_amt_vat_incl                              0.138209
# total_ship_charge_amt_vat_incl                        0.033127
# total_activity_value_amt_vat_incl                     0.994887
#
#                                    total_price_of_items_amt_vat_excl  \
# qty                                                         0.179301
# item_weight                                                -0.075137
# total_activity_weight                                      -0.074365
# price_of_items_amt_vat_excl                                 0.998960
# total_price_of_items_amt_vat_excl                           1.000000
# ship_charge_amt_vat_excl                                    0.130030
# total_ship_charge_amt_vat_excl                              0.034151
# total_activity_value_amt_vat_excl                           0.999780
# price_of_items_vat_rate_percent                             0.121666
# price_of_items_vat_amt                                      0.674910
# total_price_of_items_vat_amt                                0.676068
# ship_charge_vat_rate_percent                                0.154202
# ship_charge_vat_amt                                         0.176638
# total_ship_charge_vat_amt                                   0.017749
# total_activity_value_vat_amt                                0.675932
# price_of_items_amt_vat_incl                                 0.993841
# total_price_of_items_amt_vat_incl                           0.995476
# ship_charge_amt_vat_incl                                    0.140654
# total_ship_charge_amt_vat_incl                              0.034506
# total_activity_value_amt_vat_incl                           0.995496
#
#                                    ship_charge_amt_vat_excl  \
# qty                                               -0.017707
# item_weight                                        0.128073
# total_activity_weight                              0.080461
# price_of_items_amt_vat_excl                        0.127668
# total_price_of_items_amt_vat_excl                  0.130030
# ship_charge_amt_vat_excl                           1.000000
# total_ship_charge_amt_vat_excl                     0.848602
# total_activity_value_amt_vat_excl                  0.151246
# price_of_items_vat_rate_percent                   -0.110211
# price_of_items_vat_amt                             0.061369
# total_price_of_items_vat_amt                       0.064971
# ship_charge_vat_rate_percent                      -0.058352
# ship_charge_vat_amt                                0.511716
# total_ship_charge_vat_amt                          0.270849
# total_activity_value_vat_amt                       0.069805
# price_of_items_amt_vat_incl                        0.126118
# total_price_of_items_amt_vat_incl                  0.128813
# ship_charge_amt_vat_incl                           0.996290
# total_ship_charge_amt_vat_incl                     0.846265
# total_activity_value_amt_vat_incl                  0.149212
#
#                                    total_ship_charge_amt_vat_excl  \
# qty                                                     -0.012687
# item_weight                                              0.036320
# total_activity_weight                                    0.010308
# price_of_items_amt_vat_excl                              0.032804
# total_price_of_items_amt_vat_excl                        0.034151
# ship_charge_amt_vat_excl                                 0.848602
# total_ship_charge_amt_vat_excl                           1.000000
# total_activity_value_amt_vat_excl                        0.059481
# price_of_items_vat_rate_percent                         -0.158115
# price_of_items_vat_amt                                  -0.084508
# total_price_of_items_vat_amt                            -0.083509
# ship_charge_vat_rate_percent                            -0.119846
# ship_charge_vat_amt                                      0.147258
# total_ship_charge_vat_amt                                0.332321
# total_activity_value_vat_amt                            -0.077175
# price_of_items_amt_vat_incl                              0.020836
# total_price_of_items_amt_vat_incl                        0.022297
# ship_charge_amt_vat_incl                                 0.816705
# total_ship_charge_amt_vat_incl                           0.998104
# total_activity_value_amt_vat_incl                        0.046681
#
#                                    total_activity_value_amt_vat_excl  \
# qty                                                         0.179076
# item_weight                                                -0.075527
# total_activity_weight                                      -0.074756
# price_of_items_amt_vat_excl                                 0.998725
# total_price_of_items_amt_vat_excl                           0.999780
# ship_charge_amt_vat_excl                                    0.151246
# total_ship_charge_amt_vat_excl                              0.059481
# total_activity_value_amt_vat_excl                           1.000000
# price_of_items_vat_rate_percent                             0.118050
# price_of_items_vat_amt                                      0.672968
# total_price_of_items_vat_amt                                0.674128
# ship_charge_vat_rate_percent                                0.150800
# ship_charge_vat_amt                                         0.179966
# total_ship_charge_vat_amt                                   0.025744
# total_activity_value_vat_amt                                0.674151
# price_of_items_amt_vat_incl                                 0.993375
# total_price_of_items_amt_vat_incl                           0.995026
# ship_charge_amt_vat_incl                                    0.161031
# total_ship_charge_amt_vat_incl                              0.059764
# total_activity_value_amt_vat_incl                           0.995456
#
#                                    price_of_items_vat_rate_percent  \
# qty                                                      -0.008806
# item_weight                                              -0.153740
# total_activity_weight                                    -0.153582
# price_of_items_amt_vat_excl                               0.123266
# total_price_of_items_amt_vat_excl                         0.121666
# ship_charge_amt_vat_excl                                 -0.110211
# total_ship_charge_amt_vat_excl                           -0.158115
# total_activity_value_amt_vat_excl                         0.118050
# price_of_items_vat_rate_percent                           1.000000
# price_of_items_vat_amt                                    0.396052
# total_price_of_items_vat_amt                              0.397137
# ship_charge_vat_rate_percent                              1.000000
# ship_charge_vat_amt                                       0.208061
# total_ship_charge_vat_amt                                 0.091952
# total_activity_value_vat_amt                              0.397709
# price_of_items_amt_vat_incl                               0.163124
# total_price_of_items_amt_vat_incl                         0.161717
# ship_charge_amt_vat_incl                                 -0.083259
# total_ship_charge_amt_vat_incl                           -0.148358
# total_activity_value_amt_vat_incl                         0.158527
#
#                                    price_of_items_vat_amt  \
# qty                                              0.152205
# item_weight                                     -0.093239
# total_activity_weight                           -0.092377
# price_of_items_amt_vat_excl                      0.680358
# total_price_of_items_amt_vat_excl                0.674910
# ship_charge_amt_vat_excl                         0.061369
# total_ship_charge_amt_vat_excl                  -0.084508
# total_activity_value_amt_vat_excl                0.672968
# price_of_items_vat_rate_percent                  0.396052
# price_of_items_vat_amt                           1.000000
# total_price_of_items_vat_amt                     0.998176
# ship_charge_vat_rate_percent                     0.541037
# ship_charge_vat_amt                              0.329592
# total_ship_charge_vat_amt                        0.052665
# total_activity_value_vat_amt                     0.998116
# price_of_items_amt_vat_incl                      0.746820
# total_price_of_items_amt_vat_incl                0.741729
# ship_charge_amt_vat_incl                         0.091129
# total_ship_charge_amt_vat_incl                  -0.079063
# total_activity_value_amt_vat_incl                0.740105
#
#                                    total_price_of_items_vat_amt  \
# qty                                                    0.154923
# item_weight                                           -0.093042
# total_activity_weight                                 -0.092170
# price_of_items_amt_vat_excl                            0.678783
# total_price_of_items_amt_vat_excl                      0.676068
# ship_charge_amt_vat_excl                               0.064971
# total_ship_charge_amt_vat_excl                        -0.083509
# total_activity_value_amt_vat_excl                      0.674128
# price_of_items_vat_rate_percent                        0.397137
# price_of_items_vat_amt                                 0.998176
# total_price_of_items_vat_amt                           1.000000
# ship_charge_vat_rate_percent                           0.539497
# ship_charge_vat_amt                                    0.335410
# total_ship_charge_vat_amt                              0.054643
# total_activity_value_vat_amt                           0.999950
# price_of_items_amt_vat_incl                            0.745155
# total_price_of_items_amt_vat_incl                      0.743016
# ship_charge_amt_vat_incl                               0.095118
# total_ship_charge_amt_vat_incl                        -0.077958
# total_activity_value_amt_vat_incl                      0.741395
#
#                                    ship_charge_vat_rate_percent  \
# qty                                                   -0.092940
# item_weight                                            0.300472
# total_activity_weight                                  0.134846
# price_of_items_amt_vat_excl                            0.158369
# total_price_of_items_amt_vat_excl                      0.154202
# ship_charge_amt_vat_excl                              -0.058352
# total_ship_charge_amt_vat_excl                        -0.119846
# total_activity_value_amt_vat_excl                      0.150800
# price_of_items_vat_rate_percent                        1.000000
# price_of_items_vat_amt                                 0.541037
# total_price_of_items_vat_amt                           0.539497
# ship_charge_vat_rate_percent                           1.000000
# ship_charge_vat_amt                                    0.226578
# total_ship_charge_vat_amt                              0.100204
# total_activity_value_vat_amt                           0.540689
# price_of_items_amt_vat_incl                            0.210089
# total_price_of_items_amt_vat_incl                      0.205796
# ship_charge_amt_vat_incl                              -0.032447
# total_ship_charge_amt_vat_incl                        -0.110482
# total_activity_value_amt_vat_incl                      0.202802
#
#                                    ship_charge_vat_amt  \
# qty                                          -0.014751
# item_weight                                   0.174301
# total_activity_weight                         0.133923
# price_of_items_amt_vat_excl                   0.174528
# total_price_of_items_amt_vat_excl             0.176638
# ship_charge_amt_vat_excl                      0.511716
# total_ship_charge_amt_vat_excl                0.147258
# total_activity_value_amt_vat_excl             0.179966
# price_of_items_vat_rate_percent               0.208061
# price_of_items_vat_amt                        0.329592
# total_price_of_items_vat_amt                  0.335410
# ship_charge_vat_rate_percent                  0.226578
# ship_charge_vat_amt                           1.000000
# total_ship_charge_vat_amt                     0.524338
# total_activity_value_vat_amt                  0.342078
# price_of_items_amt_vat_incl                   0.200758
# total_price_of_items_amt_vat_incl             0.203330
# ship_charge_amt_vat_incl                      0.583760
# total_ship_charge_amt_vat_incl                0.178000
# total_activity_value_amt_vat_incl             0.207252
#
#                                    total_ship_charge_vat_amt  \
# qty                                                -0.008721
# item_weight                                        -0.017129
# total_activity_weight                              -0.017385
# price_of_items_amt_vat_excl                         0.016773
# total_price_of_items_amt_vat_excl                   0.017749
# ship_charge_amt_vat_excl                            0.270849
# total_ship_charge_amt_vat_excl                      0.332321
# total_activity_value_amt_vat_excl                   0.025744
# price_of_items_vat_rate_percent                     0.091952
# price_of_items_vat_amt                              0.052665
# total_price_of_items_vat_amt                        0.054643
# ship_charge_vat_rate_percent                        0.100204
# ship_charge_vat_amt                                 0.524338
# total_ship_charge_vat_amt                           1.000000
# total_activity_value_vat_amt                        0.067767
# price_of_items_amt_vat_incl                         0.021716
# total_price_of_items_amt_vat_incl                   0.022833
# ship_charge_amt_vat_incl                            0.308485
# total_ship_charge_amt_vat_incl                      0.389738
# total_activity_value_amt_vat_incl                   0.031807
#
#                                    total_activity_value_vat_amt  \
# qty                                                    0.154959
# item_weight                                           -0.093219
# total_activity_weight                                 -0.092347
# price_of_items_amt_vat_excl                            0.678641
# total_price_of_items_amt_vat_excl                      0.675932
# ship_charge_amt_vat_excl                               0.069805
# total_ship_charge_amt_vat_excl                        -0.077175
# total_activity_value_amt_vat_excl                      0.674151
# price_of_items_vat_rate_percent                        0.397709
# price_of_items_vat_amt                                 0.998116
# total_price_of_items_vat_amt                           0.999950
# ship_charge_vat_rate_percent                           0.540689
# ship_charge_vat_amt                                    0.342078
# total_ship_charge_vat_amt                              0.067767
# total_activity_value_vat_amt                           1.000000
# price_of_items_amt_vat_incl                            0.745018
# total_price_of_items_amt_vat_incl                      0.742886
# ship_charge_amt_vat_incl                               0.100290
# total_ship_charge_amt_vat_incl                        -0.070936
# total_activity_value_amt_vat_incl                      0.741415
#
#                                    price_of_items_amt_vat_incl  \
# qty                                                   0.182698
# item_weight                                          -0.078819
# total_activity_weight                                -0.078002
# price_of_items_amt_vat_excl                           0.995489
# total_price_of_items_amt_vat_excl                     0.993841
# ship_charge_amt_vat_excl                              0.126118
# total_ship_charge_amt_vat_excl                        0.020836
# total_activity_value_amt_vat_excl                     0.993375
# price_of_items_vat_rate_percent                       0.163124
# price_of_items_vat_amt                                0.746820
# total_price_of_items_vat_amt                          0.745155
# ship_charge_vat_rate_percent                          0.210089
# ship_charge_vat_amt                                   0.200758
# total_ship_charge_vat_amt                             0.021716
# total_activity_value_vat_amt                          0.745018
# price_of_items_amt_vat_incl                           1.000000
# total_price_of_items_amt_vat_incl                     0.998799
# ship_charge_amt_vat_incl                              0.143922
# total_ship_charge_amt_vat_incl                        0.024735
# total_activity_value_amt_vat_incl                     0.998594
#
#                                    total_price_of_items_amt_vat_incl  \
# qty                                                         0.184765
# item_weight                                                -0.078444
# total_activity_weight                                      -0.077623
# price_of_items_amt_vat_excl                                 0.994882
# total_price_of_items_amt_vat_excl                           0.995476
# ship_charge_amt_vat_excl                                    0.128813
# total_ship_charge_amt_vat_excl                              0.022297
# total_activity_value_amt_vat_excl                           0.995026
# price_of_items_vat_rate_percent                             0.161717
# price_of_items_vat_amt                                      0.741729
# total_price_of_items_vat_amt                                0.743016
# ship_charge_vat_rate_percent                                0.205796
# ship_charge_vat_amt                                         0.203330
# total_ship_charge_vat_amt                                   0.022833
# total_activity_value_vat_amt                                0.742886
# price_of_items_amt_vat_incl                                 0.998799
# total_price_of_items_amt_vat_incl                           1.000000
# ship_charge_amt_vat_incl                                    0.146682
# total_ship_charge_amt_vat_incl                              0.026206
# total_activity_value_amt_vat_incl                           0.999810
#
#                                    ship_charge_amt_vat_incl  \
# qty                                               -0.017530
# item_weight                                        0.138090
# total_activity_weight                              0.089982
# price_of_items_amt_vat_excl                        0.138209
# total_price_of_items_amt_vat_excl                  0.140654
# ship_charge_amt_vat_excl                           0.996290
# total_ship_charge_amt_vat_excl                     0.816705
# total_activity_value_amt_vat_excl                  0.161031
# price_of_items_vat_rate_percent                   -0.083259
# price_of_items_vat_amt                             0.091129
# total_price_of_items_vat_amt                       0.095118
# ship_charge_vat_rate_percent                      -0.032447
# ship_charge_vat_amt                                0.583760
# total_ship_charge_vat_amt                          0.308485
# total_activity_value_vat_amt                       0.100290
# price_of_items_amt_vat_incl                        0.143922
# total_price_of_items_amt_vat_incl                  0.146682
# ship_charge_amt_vat_incl                           1.000000
# total_ship_charge_amt_vat_incl                     0.817581
# total_activity_value_amt_vat_incl                  0.166173
#
#                                    total_ship_charge_amt_vat_incl  \
# qty                                                     -0.012574
# item_weight                                              0.034568
# total_activity_weight                                    0.009543
# price_of_items_amt_vat_excl                              0.033127
# total_price_of_items_amt_vat_excl                        0.034506
# ship_charge_amt_vat_excl                                 0.846265
# total_ship_charge_amt_vat_excl                           0.998104
# total_activity_value_amt_vat_excl                        0.059764
# price_of_items_vat_rate_percent                         -0.148358
# price_of_items_vat_amt                                  -0.079063
# total_price_of_items_vat_amt                            -0.077958
# ship_charge_vat_rate_percent                            -0.110482
# ship_charge_vat_amt                                      0.178000
# total_ship_charge_vat_amt                                0.389738
# total_activity_value_vat_amt                            -0.070936
# price_of_items_amt_vat_incl                              0.024735
# total_price_of_items_amt_vat_incl                        0.026206
# ship_charge_amt_vat_incl                                 0.817581
# total_ship_charge_amt_vat_incl                           1.000000
# total_activity_value_amt_vat_incl                        0.050420
#
#                                    total_activity_value_amt_vat_incl
# qty                                                         0.184610
# item_weight                                                -0.078836
# total_activity_weight                                      -0.078015
# price_of_items_amt_vat_excl                                 0.994887
# total_price_of_items_amt_vat_excl                           0.995496
# ship_charge_amt_vat_excl                                    0.149212
# total_ship_charge_amt_vat_excl                              0.046681
# total_activity_value_amt_vat_excl                           0.995456
# price_of_items_vat_rate_percent                             0.158527
# price_of_items_vat_amt                                      0.740105
# total_price_of_items_vat_amt                                0.741395
# ship_charge_vat_rate_percent                                0.202802
# ship_charge_vat_amt                                         0.207252
# total_ship_charge_vat_amt                                   0.031807
# total_activity_value_vat_amt                                0.741415
# price_of_items_amt_vat_incl                                 0.998594
# total_price_of_items_amt_vat_incl                           0.999810
# ship_charge_amt_vat_incl                                    0.166173
# total_ship_charge_amt_vat_incl                              0.050420
# total_activity_value_amt_vat_incl                           1.000000
