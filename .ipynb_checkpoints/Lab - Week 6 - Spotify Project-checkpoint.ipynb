# %%
import config
import spotipy
import json
import pprint
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id= config.client_id,
    client_secret= config.client_secret)
)

# %%
playlists = []
for i in range(23):
    playlists.extend(sp.user_playlists('Spotify', limit=50, offset=i*50)['items'])
len(playlists)
# Out:
# 1112

# %%
playlist_ids = []
for playlist in playlists:
    playlist_ids.append(playlist['id'])
len(playlist_ids)
#playlist_ids
# Out:
# 1112

# %%
song_ids = []

for playlist_id in playlist_ids:
    playlist_songs = sp.user_playlist_tracks("spotify", playlist_id, market="US", limit=5)['items']
    while None in playlist_songs:
        playlist_songs.remove(None)
    for song in playlist_songs:
        try:
            song_ids.append(song['track']['id'])
        except TypeError:
            print("---- ", song)
            pass
# Out:
# ----  {'added_at': '2023-08-21T15:41:01Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}, 'is_local': False, 'primary_color': None, 'track': None, 'video_thumbnail': {'url': None}}

# %%
audio_list = []
for song_id in song_ids:
    try:
        audio_list.append(sp.audio_features(song_id)[0])
    except TypeError:
        pass
    
while None in audio_list:
    audio_list.remove(None)
len(audio_list)
# Out:
# 5532

# %%
audio_features_df = pd.DataFrame(list(audio_list))
audio_features_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.546   0.846    5    -5.719     1       0.1810        0.0135
# 1            0.868   0.538    5    -8.603     1       0.1740        0.2690
# 2            0.552   0.702    9    -5.707     1       0.1570        0.1170
# 3            0.671   0.845   11    -4.930     0       0.0480        0.0207
# 4            0.802   0.832   11    -4.107     1       0.0434        0.3110
# ...            ...     ...  ...       ...   ...          ...           ...
# 5527         0.781   0.445    2    -6.061     1       0.0295        0.4740
# 5528         0.422   0.264    8    -7.064     1       0.0322        0.9220
# 5529         0.418   0.420    0    -6.444     1       0.0414        0.5880
# 5530         0.745   0.219    5   -11.216     1       0.0276        0.8510
# 5531         0.484   0.312    2   -13.522     1       0.0535        0.7240
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.6070    0.740  162.043  audio_features
# 1             0.000003    0.0901    0.732   99.968  audio_features
# 2             0.000021    0.1050    0.564  169.994  audio_features
# 3             0.000000    0.3290    0.775  110.056  audio_features
# 4             0.000000    0.0815    0.890  124.997  audio_features
# ...                ...       ...      ...      ...             ...
# 5527          0.000000    0.1840    0.591   78.998  audio_features
# 5528          0.000000    0.1320    0.331  119.930  audio_features
# 5529          0.000064    0.1100    0.184   84.094  audio_features
# 5530          0.000018    0.0678    0.635   88.609  audio_features
# 5531          0.000002    0.0601    0.598  205.981  audio_features
#
#                           id                                   uri  \
# 0     2gyxAWHebV7xPYVxqoi86f  spotify:track:2gyxAWHebV7xPYVxqoi86f
# 1     2IGMVunIBsBLtEQyoI1Mu7  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 2     1BxfuPKGuaTgP7aM0Bbdwr  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 3     1vYXt7VSjH9JIM5oRRo7vA  spotify:track:1vYXt7VSjH9JIM5oRRo7vA
# 4     7x9aauaA9cu6tyfpHnqDLo  spotify:track:7x9aauaA9cu6tyfpHnqDLo
# ...                      ...                                   ...
# 5527  34gCuhDGsG4bRPIf9bb02f  spotify:track:34gCuhDGsG4bRPIf9bb02f
# 5528  3U4isOIWM3VvDubwSI3y7a  spotify:track:3U4isOIWM3VvDubwSI3y7a
# 5529  5Nm9ERjJZ5oyfXZTECKmRt  spotify:track:5Nm9ERjJZ5oyfXZTECKmRt
# 5530  1zNXF2svmdlNxfS5XeNUgr  spotify:track:1zNXF2svmdlNxfS5XeNUgr
# 5531  4Y4Gd3ty8uut6Qw43c7yJc  spotify:track:4Y4Gd3ty8uut6Qw43c7yJc
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2gyxAWHebV7x...
# 1     https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 2     https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 3     https://api.spotify.com/v1/tracks/1vYXt7VSjH9J...
# 4     https://api.spotify.com/v1/tracks/7x9aauaA9cu6...
# ...                                                 ...
# 5527  https://api.spotify.com/v1/tracks/34gCuhDGsG4b...
# 5528  https://api.spotify.com/v1/tracks/3U4isOIWM3Vv...
# 5529  https://api.spotify.com/v1/tracks/5Nm9ERjJZ5oy...
# 5530  https://api.spotify.com/v1/tracks/1zNXF2svmdlN...
# 5531  https://api.spotify.com/v1/tracks/4Y4Gd3ty8uut...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2gyx...       211141
# 1     https://api.spotify.com/v1/audio-analysis/2IGM...       231750
# 2     https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# 3     https://api.spotify.com/v1/audio-analysis/1vYX...       176579
# 4     https://api.spotify.com/v1/audio-analysis/7x9a...       185427
# ...                                                 ...          ...
# 5527  https://api.spotify.com/v1/audio-analysis/34gC...       281560
# 5528  https://api.spotify.com/v1/audio-analysis/3U4i...       269560
# 5529  https://api.spotify.com/v1/audio-analysis/5Nm9...       172724
# 5530  https://api.spotify.com/v1/audio-analysis/1zNX...       186251
# 5531  https://api.spotify.com/v1/audio-analysis/4Y4G...       166827
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 5527               4
# 5528               4
# 5529               4
# 5530               4
# 5531               4
#
# [5532 rows x 18 columns]

# %%
audio_features_df.to_csv('audio_features_df.csv')
